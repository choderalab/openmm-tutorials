# %% [markdown]
# # Creating and importing molecular systems in OpenMM

# %% [markdown]
# ## Preliminaries
#
# First, we import OpenMM. It's recommended that you always import this way:

# %%
from simtk import openmm, unit
from simtk.openmm import app
import numpy as np

# %% [markdown]
# ## The OpenMM `System` object
#
# The OpenMM [`System`](http://docs.openmm.org/7.1.0/api-python/library.html#system) object is a container that completely specifies how to compute the forces and energies for all particles in the molecular system.
#
# Because it is part of the C++ OpenMM API, `System` (and the related `Force` classes) are not true Python objects but instead SWIG-wrapped C++ objects, so you will find their naming and accessor conventions conform to C++ (rather than Pythonic) standards.
#
# There are many ways to create or import OpenMM `System` objects:
# * We can assemble all the particles and define their interactions ourselves programmatically using the OpenMM C++ API
# * We could load in a serialized version of the `System` object via the built-in XML serializer
# * We can use the various importers in the [`simtk.openmm.app`](http://docs.openmm.org/7.1.0/api-python/app.html) layer to read in a system definition in AMBER, CHARMM, or gromacs format
# * We can create our own `System` object from a PDB file using the OpenMM [`ForceField`](http://docs.openmm.org/7.1.0/userguide/application.html#force-fields) facility
# * We can use a large variety of pre-built test systems provided by the [`openmmtools.testsystems`](http://openmmtools.readthedocs.io) module for testing code on a battery of different system types with different kinds of forces
#
# Remember that if you want more information on `openmm.System`, you can use `help(openmm.System)`:

# %% [markdown]
# ## Creating a periodic Lennard-Jones system
#
# We'll start by building a simple periodic Lennard-Jones system using the Python wrappers for the main OpenMM C++ API.

# %%
# Define the parameters of the Lennard-Jones periodic system
nparticles = 512
reduced_density = 0.05
mass = 39.9 * unit.amu
charge = 0.0 * unit.elementary_charge
sigma = 3.4 * unit.angstroms
epsilon = 0.238 * unit.kilocalories_per_mole

# Create a system and add particles to it
system = openmm.System()
for index in range(nparticles):
    # Particles are added one at a time
    # Their indices in the System will correspond with their indices in the Force objects we will add later
    system.addParticle(mass)
    
# Set the periodic box vectors
number_density = reduced_density / sigma**3
volume = nparticles * (number_density ** -1)
box_edge = volume ** (1. / 3.)
box_vectors = np.diag([box_edge/unit.angstrom for i in range(3)]) * unit.angstroms
system.setDefaultPeriodicBoxVectors(*box_vectors)

# Add Lennard-Jones interactions using a NonbondedForce
force = openmm.NonbondedForce()
force.setNonbondedMethod(openmm.NonbondedForce.CutoffPeriodic)
for index in range(nparticles): # all particles must have parameters assigned for the NonbondedForce
    # Particles are assigned properties in the same order as they appear in the System object
    force.addParticle(charge, sigma, epsilon)
force.setCutoffDistance(3.0 * sigma) # set cutoff (truncation) distance at 3*sigma
force.setUseSwitchingFunction(True) # use a smooth switching function to avoid force discontinuities at cutoff
force.setSwitchingDistance(2.5 * sigma) # turn on switch at 2.5*sigma
force.setUseDispersionCorrection(True) # use long-range isotropic dispersion correction
force_index = system.addForce(force) # system takes ownership of the NonbondedForce object

# %% [markdown]
# ### The OpenMM Python API uses units throughout
#
# Note the use of unit-bearing quantities via [`simtk.unit`](). OpenMM's Python API uses a powerful units system that prevents many common kinds of mistakes with unit conversion, such as those that caused the loss of the [Mars Polar Lander](). We'll examine the units system in more detail later---for now, we simply recognize that best practices dictate we feed OpenMM unit-bearing quantities (though this is not strictly necessary), and that it will return unit-bearing quantities.

# %%
help(unit)
# Out:
# Help on package simtk.unit in simtk:
#
# NAME
#     simtk.unit - Physical quantities with units for dimensional analysis and automatic unit conversion.
#
# PACKAGE CONTENTS
#     basedimension
#     baseunit
#     constants
#     doctests
#     mymatrix
#     prefix
#     quantity
#     standard_dimensions
#     unit
#     unit_definitions
#     unit_math
#     unit_operators
#
# DATA
#     AVOGADRO_CONSTANT_NA = Quantity(value=6.02214179e+23, unit=/mole)
#     BOLTZMANN_CONSTANT_kB = Quantity(value=1.3806504e-23, unit=joule/kelvi...
#     GRAVITATIONAL_CONSTANT_G = Quantity(value=6.6742e-11, unit=meter**2*ne...
#     MOLAR_GAS_CONSTANT_R = Quantity(value=8.314472471220217, unit=joule/(k...
#     SPEED_OF_LIGHT_C = Quantity(value=299792458.0, unit=meter/second)
#     __copyright__ = 'Copyright 2010, Stanford University and Christopher M...
#     __docformat__ = 'epytext en'
#     __email__ = 'cmbruns@stanford.edu'
#     __license__ = 'MIT'
#     __maintainer__ = 'Christopher M. Bruns'
#     absolute_import = _Feature((2, 5, 0, 'alpha', 1), (3, 0, 0, 'alpha', 0...
#     amount_dimension = BaseDimension("amount")
#     amp = Unit({ScaledUnit(factor=1.0, master=coulomb/second, name='ampere...
#     ampere = Unit({ScaledUnit(factor=1.0, master=coulomb/second, name='amp...
#     ampere_base_unit = ScaledUnit(factor=1.0, master=coulomb/second, name=...
#     amperes = Unit({ScaledUnit(factor=1.0, master=coulomb/second, name='am...
#     amps = Unit({ScaledUnit(factor=1.0, master=coulomb/second, name='amper...
#     amu = Unit({ScaledUnit(factor=1.0, master=gram/mole, name='dalton', sy...
#     amus = Unit({ScaledUnit(factor=1.0, master=gram/mole, name='dalton', s...
#     angle_dimension = BaseDimension("angle")
#     angstrom = Unit({BaseUnit(base_dim=BaseDimension("length"), name="angs...
#     angstrom_base_unit = BaseUnit(base_dim=BaseDimension("length"), name="...
#     angstroms = Unit({BaseUnit(base_dim=BaseDimension("length"), name="ang...
#     arcminute = Unit({BaseUnit(base_dim=BaseDimension("angle"), name="arcm...
#     arcminutes = Unit({BaseUnit(base_dim=BaseDimension("angle"), name="arc...
#     arcsecond = Unit({BaseUnit(base_dim=BaseDimension("angle"), name="arcs...
#     arcseconds = Unit({BaseUnit(base_dim=BaseDimension("angle"), name="arc...
#     atmosphere = Unit({ScaledUnit(factor=101325.0, master=pascal, name='at...
#     atmosphere_base_unit = ScaledUnit(factor=101325.0, master=pascal, name...
#     atmospheres = Unit({ScaledUnit(factor=101325.0, master=pascal, name='a...
#     atom_mass_units = Unit({ScaledUnit(factor=1.0, master=gram/mole, name=...
#     atomic_mass_unit = Unit({ScaledUnit(factor=1.0, master=gram/mole, name...
#     atto = <simtk.unit.prefix.SiPrefix object>
#     attocalorie = Unit({ScaledUnit(factor=4.184e-18, master=joule, name='a...
#     attocalorie_base_unit = ScaledUnit(factor=4.184e-18, master=joule, nam...
#     attocalories = Unit({ScaledUnit(factor=4.184e-18, master=joule, name='...
#     attogram = Unit({BaseUnit(base_dim=BaseDimension("mass"), name="attogr...
#     attogram_base_unit = BaseUnit(base_dim=BaseDimension("mass"), name="at...
#     attograms = Unit({BaseUnit(base_dim=BaseDimension("mass"), name="attog...
#     attojoule = Unit({ScaledUnit(factor=1e-18, master=meter*newton, name='...
#     attojoule_base_unit = ScaledUnit(factor=1e-18, master=meter*newton, na...
#     attojoules = Unit({ScaledUnit(factor=1e-18, master=meter*newton, name=...
#     attoliter = Unit({ScaledUnit(factor=1e-18, master=decimeter**3, name='...
#     attoliter_base_unit = ScaledUnit(factor=1e-18, master=decimeter**3, na...
#     attoliters = Unit({ScaledUnit(factor=1e-18, master=decimeter**3, name=...
#     attometer = Unit({BaseUnit(base_dim=BaseDimension("length"), name="att...
#     attometer_base_unit = BaseUnit(base_dim=BaseDimension("length"), name=...
#     attometers = Unit({BaseUnit(base_dim=BaseDimension("length"), name="at...
#     attomolar = Unit({ScaledUnit(factor=1e-18, master=mole/liter, name='at...
#     attomolar_base_unit = ScaledUnit(factor=1e-18, master=mole/liter, name...
#     attomolars = Unit({ScaledUnit(factor=1e-18, master=mole/liter, name='a...
#     attonewton = Unit({ScaledUnit(factor=1e-18, master=kilogram*m...econd*...
#     attonewton_base_unit = ScaledUnit(factor=1e-18, master=kilogram*meter/...
#     attonewtons = Unit({ScaledUnit(factor=1e-18, master=kilogram*m...econd...
#     attopascal = Unit({ScaledUnit(factor=1e-18, master=newton/(meter**2), ...
#     attopascal_base_unit = ScaledUnit(factor=1e-18, master=newton/(meter**...
#     attopascals = Unit({ScaledUnit(factor=1e-18, master=newton/(meter**2),...
#     attosecond = Unit({BaseUnit(base_dim=BaseDimension("time"), name="atto...
#     attosecond_base_unit = BaseUnit(base_dim=BaseDimension("time"), name="...
#     attoseconds = Unit({BaseUnit(base_dim=BaseDimension("time"), name="att...
#     ban = Unit({BaseUnit(base_dim=BaseDimension("information"), name="ban"...
#     ban_base_unit = BaseUnit(base_dim=BaseDimension("information"), name="...
#     bans = Unit({BaseUnit(base_dim=BaseDimension("information"), name="ban...
#     bar = Unit({ScaledUnit(factor=100000.0, master=pascal, name='bar', sym...
#     bar_base_unit = ScaledUnit(factor=100000.0, master=pascal, name='bar',...
#     bars = Unit({ScaledUnit(factor=100000.0, master=pascal, name='bar', sy...
#     binary_prefixes = (<simtk.unit.prefix.SiPrefix object>, <simtk.unit.pr...
#     bit = Unit({BaseUnit(base_dim=BaseDimension("information"), name="bit"...
#     bit_base_unit = BaseUnit(base_dim=BaseDimension("information"), name="...
#     bits = Unit({BaseUnit(base_dim=BaseDimension("information"), name="bit...
#     byte = Unit({BaseUnit(base_dim=BaseDimension("information"), name="byt...
#     byte_base_unit = BaseUnit(base_dim=BaseDimension("information"), name=...
#     bytes = Unit({BaseUnit(base_dim=BaseDimension("information"), name="by...
#     calorie = Unit({ScaledUnit(factor=4.184, master=joule, name='calorie',...
#     calorie_base_unit = ScaledUnit(factor=4.184, master=joule, name='calor...
#     calories = Unit({ScaledUnit(factor=4.184, master=joule, name='calorie'...
#     candela = Unit({BaseUnit(base_dim=BaseDimension("luminous intensity"),...
#     candela_base_unit = BaseUnit(base_dim=BaseDimension("luminous intensit...
#     candelas = Unit({BaseUnit(base_dim=BaseDimension("luminous intensity")...
#     centi = <simtk.unit.prefix.SiPrefix object>
#     centicalorie = Unit({ScaledUnit(factor=0.04184, master=joule, name='ce...
#     centicalorie_base_unit = ScaledUnit(factor=0.04184, master=joule, name...
#     centicalories = Unit({ScaledUnit(factor=0.04184, master=joule, name='c...
#     centigram = Unit({BaseUnit(base_dim=BaseDimension("mass"), name="centi...
#     centigram_base_unit = BaseUnit(base_dim=BaseDimension("mass"), name="c...
#     centigrams = Unit({BaseUnit(base_dim=BaseDimension("mass"), name="cent...
#     centijoule = Unit({ScaledUnit(factor=0.01, master=meter*newton, name='...
#     centijoule_base_unit = ScaledUnit(factor=0.01, master=meter*newton, na...
#     centijoules = Unit({ScaledUnit(factor=0.01, master=meter*newton, name=...
#     centiliter = Unit({ScaledUnit(factor=0.01, master=decimeter**3, name='...
#     centiliter_base_unit = ScaledUnit(factor=0.01, master=decimeter**3, na...
#     centiliters = Unit({ScaledUnit(factor=0.01, master=decimeter**3, name=...
#     centimeter = Unit({BaseUnit(base_dim=BaseDimension("length"), name="ce...
#     centimeter_base_unit = BaseUnit(base_dim=BaseDimension("length"), name...
#     centimeters = Unit({BaseUnit(base_dim=BaseDimension("length"), name="c...
#     centimolar = Unit({ScaledUnit(factor=0.01, master=mole/liter, name='ce...
#     centimolar_base_unit = ScaledUnit(factor=0.01, master=mole/liter, name...
#     centimolars = Unit({ScaledUnit(factor=0.01, master=mole/liter, name='c...
#     centinewton = Unit({ScaledUnit(factor=0.01, master=kilogram*me...cond*...
#     centinewton_base_unit = ScaledUnit(factor=0.01, master=kilogram*meter/...
#     centinewtons = Unit({ScaledUnit(factor=0.01, master=kilogram*me...cond...
#     centipascal = Unit({ScaledUnit(factor=0.01, master=newton/(meter**2), ...
#     centipascal_base_unit = ScaledUnit(factor=0.01, master=newton/(meter**...
#     centipascals = Unit({ScaledUnit(factor=0.01, master=newton/(meter**2),...
#     centisecond = Unit({BaseUnit(base_dim=BaseDimension("time"), name="cen...
#     centisecond_base_unit = BaseUnit(base_dim=BaseDimension("time"), name=...
#     centiseconds = Unit({BaseUnit(base_dim=BaseDimension("time"), name="ce...
#     centuries = Unit({BaseUnit(base_dim=BaseDimension("time"), name="centu...
#     century = Unit({BaseUnit(base_dim=BaseDimension("time"), name="century...
#     centurys = Unit({BaseUnit(base_dim=BaseDimension("time"), name="centur...
#     cgs_unit_system = <simtk.unit.unit.UnitSystem object>
#     charge_dimension = BaseDimension("charge")
#     coulomb = Unit({BaseUnit(base_dim=BaseDimension("charge"), name="coulo...
#     coulomb_base_unit = BaseUnit(base_dim=BaseDimension("charge"), name="c...
#     coulombs = Unit({BaseUnit(base_dim=BaseDimension("charge"), name="coul...
#     dalton = Unit({ScaledUnit(factor=1.0, master=gram/mole, name='dalton',...
#     dalton_base_unit = ScaledUnit(factor=1.0, master=gram/mole, name='dalt...
#     daltons = Unit({ScaledUnit(factor=1.0, master=gram/mole, name='dalton'...
#     day = Unit({BaseUnit(base_dim=BaseDimension("time"), name="day", symbo...
#     days = Unit({BaseUnit(base_dim=BaseDimension("time"), name="day", symb...
#     debye = Unit({ScaledUnit(factor=0.20822678, master=angst...ementary ch...
#     debye_base_unit = ScaledUnit(factor=0.20822678, master=angstrom*elemen...
#     debyes = Unit({ScaledUnit(factor=0.20822678, master=angst...ementary c...
#     deca = <simtk.unit.prefix.SiPrefix object>
#     decacalorie = Unit({ScaledUnit(factor=41.84, master=joule, name='decac...
#     decacalorie_base_unit = ScaledUnit(factor=41.84, master=joule, name='d...
#     decacalories = Unit({ScaledUnit(factor=41.84, master=joule, name='deca...
#     decagram = Unit({BaseUnit(base_dim=BaseDimension("mass"), name="decagr...
#     decagram_base_unit = BaseUnit(base_dim=BaseDimension("mass"), name="de...
#     decagrams = Unit({BaseUnit(base_dim=BaseDimension("mass"), name="decag...
#     decajoule = Unit({ScaledUnit(factor=10.0, master=meter*newton, name='d...
#     decajoule_base_unit = ScaledUnit(factor=10.0, master=meter*newton, nam...
#     decajoules = Unit({ScaledUnit(factor=10.0, master=meter*newton, name='...
#     decaliter = Unit({ScaledUnit(factor=10.0, master=decimeter**3, name='d...
#     decaliter_base_unit = ScaledUnit(factor=10.0, master=decimeter**3, nam...
#     decaliters = Unit({ScaledUnit(factor=10.0, master=decimeter**3, name='...
#     decameter = Unit({BaseUnit(base_dim=BaseDimension("length"), name="dec...
#     decameter_base_unit = BaseUnit(base_dim=BaseDimension("length"), name=...
#     decameters = Unit({BaseUnit(base_dim=BaseDimension("length"), name="de...
#     decamolar = Unit({ScaledUnit(factor=10.0, master=mole/liter, name='dec...
#     decamolar_base_unit = ScaledUnit(factor=10.0, master=mole/liter, name=...
#     decamolars = Unit({ScaledUnit(factor=10.0, master=mole/liter, name='de...
#     decanewton = Unit({ScaledUnit(factor=10.0, master=kilogram*me...cond**...
#     decanewton_base_unit = ScaledUnit(factor=10.0, master=kilogram*meter/(...
#     decanewtons = Unit({ScaledUnit(factor=10.0, master=kilogram*me...cond*...
#     decapascal = Unit({ScaledUnit(factor=10.0, master=newton/(meter**2), n...
#     decapascal_base_unit = ScaledUnit(factor=10.0, master=newton/(meter**2...
#     decapascals = Unit({ScaledUnit(factor=10.0, master=newton/(meter**2), ...
#     decasecond = Unit({BaseUnit(base_dim=BaseDimension("time"), name="deca...
#     decasecond_base_unit = BaseUnit(base_dim=BaseDimension("time"), name="...
#     decaseconds = Unit({BaseUnit(base_dim=BaseDimension("time"), name="dec...
#     deci = <simtk.unit.prefix.SiPrefix object>
#     decicalorie = Unit({ScaledUnit(factor=0.41840000000000005, master=joul...
#     decicalorie_base_unit = ScaledUnit(factor=0.41840000000000005, master=...
#     decicalories = Unit({ScaledUnit(factor=0.41840000000000005, master=jou...
#     decigram = Unit({BaseUnit(base_dim=BaseDimension("mass"), name="decigr...
#     decigram_base_unit = BaseUnit(base_dim=BaseDimension("mass"), name="de...
#     decigrams = Unit({BaseUnit(base_dim=BaseDimension("mass"), name="decig...
#     decijoule = Unit({ScaledUnit(factor=0.1, master=meter*newton, name='de...
#     decijoule_base_unit = ScaledUnit(factor=0.1, master=meter*newton, name...
#     decijoules = Unit({ScaledUnit(factor=0.1, master=meter*newton, name='d...
#     deciliter = Unit({ScaledUnit(factor=0.1, master=decimeter**3, name='de...
#     deciliter_base_unit = ScaledUnit(factor=0.1, master=decimeter**3, name...
#     deciliters = Unit({ScaledUnit(factor=0.1, master=decimeter**3, name='d...
#     decimeter = Unit({BaseUnit(base_dim=BaseDimension("length"), name="dec...
#     decimeter_base_unit = BaseUnit(base_dim=BaseDimension("length"), name=...
#     decimeters = Unit({BaseUnit(base_dim=BaseDimension("length"), name="de...
#     decimolar = Unit({ScaledUnit(factor=0.1, master=mole/liter, name='deci...
#     decimolar_base_unit = ScaledUnit(factor=0.1, master=mole/liter, name='...
#     decimolars = Unit({ScaledUnit(factor=0.1, master=mole/liter, name='dec...
#     decinewton = Unit({ScaledUnit(factor=0.1, master=kilogram*met...econd*...
#     decinewton_base_unit = ScaledUnit(factor=0.1, master=kilogram*meter/(s...
#     decinewtons = Unit({ScaledUnit(factor=0.1, master=kilogram*met...econd...
#     decipascal = Unit({ScaledUnit(factor=0.1, master=newton/(meter**2), na...
#     decipascal_base_unit = ScaledUnit(factor=0.1, master=newton/(meter**2)...
#     decipascals = Unit({ScaledUnit(factor=0.1, master=newton/(meter**2), n...
#     decisecond = Unit({BaseUnit(base_dim=BaseDimension("time"), name="deci...
#     decisecond_base_unit = BaseUnit(base_dim=BaseDimension("time"), name="...
#     deciseconds = Unit({BaseUnit(base_dim=BaseDimension("time"), name="dec...
#     degree = Unit({BaseUnit(base_dim=BaseDimension("angle"), name="degree"...
#     degree_base_unit = BaseUnit(base_dim=BaseDimension("angle"), name="deg...
#     degrees = Unit({BaseUnit(base_dim=BaseDimension("angle"), name="degree...
#     deka = <simtk.unit.prefix.SiPrefix object>
#     dekacalorie = Unit({ScaledUnit(factor=41.84, master=joule, name='dekac...
#     dekacalorie_base_unit = ScaledUnit(factor=41.84, master=joule, name='d...
#     dekacalories = Unit({ScaledUnit(factor=41.84, master=joule, name='deka...
#     dekagram = Unit({BaseUnit(base_dim=BaseDimension("mass"), name="dekagr...
#     dekagram_base_unit = BaseUnit(base_dim=BaseDimension("mass"), name="de...
#     dekagrams = Unit({BaseUnit(base_dim=BaseDimension("mass"), name="dekag...
#     dekajoule = Unit({ScaledUnit(factor=10.0, master=meter*newton, name='d...
#     dekajoule_base_unit = ScaledUnit(factor=10.0, master=meter*newton, nam...
#     dekajoules = Unit({ScaledUnit(factor=10.0, master=meter*newton, name='...
#     dekaliter = Unit({ScaledUnit(factor=10.0, master=decimeter**3, name='d...
#     dekaliter_base_unit = ScaledUnit(factor=10.0, master=decimeter**3, nam...
#     dekaliters = Unit({ScaledUnit(factor=10.0, master=decimeter**3, name='...
#     dekameter = Unit({BaseUnit(base_dim=BaseDimension("length"), name="dek...
#     dekameter_base_unit = BaseUnit(base_dim=BaseDimension("length"), name=...
#     dekameters = Unit({BaseUnit(base_dim=BaseDimension("length"), name="de...
#     dekamolar = Unit({ScaledUnit(factor=10.0, master=mole/liter, name='dek...
#     dekamolar_base_unit = ScaledUnit(factor=10.0, master=mole/liter, name=...
#     dekamolars = Unit({ScaledUnit(factor=10.0, master=mole/liter, name='de...
#     dekanewton = Unit({ScaledUnit(factor=10.0, master=kilogram*me...cond**...
#     dekanewton_base_unit = ScaledUnit(factor=10.0, master=kilogram*meter/(...
#     dekanewtons = Unit({ScaledUnit(factor=10.0, master=kilogram*me...cond*...
#     dekapascal = Unit({ScaledUnit(factor=10.0, master=newton/(meter**2), n...
#     dekapascal_base_unit = ScaledUnit(factor=10.0, master=newton/(meter**2...
#     dekapascals = Unit({ScaledUnit(factor=10.0, master=newton/(meter**2), ...
#     dekasecond = Unit({BaseUnit(base_dim=BaseDimension("time"), name="deka...
#     dekasecond_base_unit = BaseUnit(base_dim=BaseDimension("time"), name="...
#     dekaseconds = Unit({BaseUnit(base_dim=BaseDimension("time"), name="dek...
#     dimensionless = Unit({})
#     dit = Unit({BaseUnit(base_dim=BaseDimension("information"), name="ban"...
#     dits = Unit({BaseUnit(base_dim=BaseDimension("information"), name="ban...
#     division = _Feature((2, 2, 0, 'alpha', 2), (3, 0, 0, 'alpha', 0), 8192...
#     dyne = Unit({ScaledUnit(factor=1.0, master=gram*centimeter/(second**2)...
#     dyne_base_unit = ScaledUnit(factor=1.0, master=gram*centimeter/(second...
#     dynes = Unit({ScaledUnit(factor=1.0, master=gram*centimeter/(second**2...
#     elementary_charge = Unit({BaseUnit(base_dim=BaseDimension("charge"), n...
#     elementary_charge_base_unit = BaseUnit(base_dim=BaseDimension("charge"...
#     elementary_charges = Unit({BaseUnit(base_dim=BaseDimension("charge"), ...
#     erg = Unit({ScaledUnit(factor=1.0, master=centimeter*dyne, name='erg',...
#     erg_base_unit = ScaledUnit(factor=1.0, master=centimeter*dyne, name='e...
#     ergs = Unit({ScaledUnit(factor=1.0, master=centimeter*dyne, name='erg'...
#     exa = <simtk.unit.prefix.SiPrefix object>
#     exacalorie = Unit({ScaledUnit(factor=4.184e+18, master=joule, name='ex...
#     exacalorie_base_unit = ScaledUnit(factor=4.184e+18, master=joule, name...
#     exacalories = Unit({ScaledUnit(factor=4.184e+18, master=joule, name='e...
#     exagram = Unit({BaseUnit(base_dim=BaseDimension("mass"), name="exagram...
#     exagram_base_unit = BaseUnit(base_dim=BaseDimension("mass"), name="exa...
#     exagrams = Unit({BaseUnit(base_dim=BaseDimension("mass"), name="exagra...
#     exajoule = Unit({ScaledUnit(factor=1e+18, master=meter*newton, name='e...
#     exajoule_base_unit = ScaledUnit(factor=1e+18, master=meter*newton, nam...
#     exajoules = Unit({ScaledUnit(factor=1e+18, master=meter*newton, name='...
#     exaliter = Unit({ScaledUnit(factor=1e+18, master=decimeter**3, name='e...
#     exaliter_base_unit = ScaledUnit(factor=1e+18, master=decimeter**3, nam...
#     exaliters = Unit({ScaledUnit(factor=1e+18, master=decimeter**3, name='...
#     exameter = Unit({BaseUnit(base_dim=BaseDimension("length"), name="exam...
#     exameter_base_unit = BaseUnit(base_dim=BaseDimension("length"), name="...
#     exameters = Unit({BaseUnit(base_dim=BaseDimension("length"), name="exa...
#     examolar = Unit({ScaledUnit(factor=1e+18, master=mole/liter, name='exa...
#     examolar_base_unit = ScaledUnit(factor=1e+18, master=mole/liter, name=...
#     examolars = Unit({ScaledUnit(factor=1e+18, master=mole/liter, name='ex...
#     exanewton = Unit({ScaledUnit(factor=1e+18, master=kilogram*m...second*...
#     exanewton_base_unit = ScaledUnit(factor=1e+18, master=kilogram*meter/(...
#     exanewtons = Unit({ScaledUnit(factor=1e+18, master=kilogram*m...second...
#     exapascal = Unit({ScaledUnit(factor=1e+18, master=newton/(meter**2), n...
#     exapascal_base_unit = ScaledUnit(factor=1e+18, master=newton/(meter**2...
#     exapascals = Unit({ScaledUnit(factor=1e+18, master=newton/(meter**2), ...
#     exasecond = Unit({BaseUnit(base_dim=BaseDimension("time"), name="exase...
#     exasecond_base_unit = BaseUnit(base_dim=BaseDimension("time"), name="e...
#     exaseconds = Unit({BaseUnit(base_dim=BaseDimension("time"), name="exas...
#     exbi = <simtk.unit.prefix.SiPrefix object>
#     farad = Unit({ScaledUnit(factor=1.0, master=coulomb/volt, name='farad'...
#     farad_base_unit = ScaledUnit(factor=1.0, master=coulomb/volt, name='fa...
#     farads = Unit({ScaledUnit(factor=1.0, master=coulomb/volt, name='farad...
#     feet = Unit({BaseUnit(base_dim=BaseDimension("length"), name="foot", s...
#     femto = <simtk.unit.prefix.SiPrefix object>
#     femtocalorie = Unit({ScaledUnit(factor=4.184e-15, master=joule, name='...
#     femtocalorie_base_unit = ScaledUnit(factor=4.184e-15, master=joule, na...
#     femtocalories = Unit({ScaledUnit(factor=4.184e-15, master=joule, name=...
#     femtogram = Unit({BaseUnit(base_dim=BaseDimension("mass"), name="femto...
#     femtogram_base_unit = BaseUnit(base_dim=BaseDimension("mass"), name="f...
#     femtograms = Unit({BaseUnit(base_dim=BaseDimension("mass"), name="femt...
#     femtojoule = Unit({ScaledUnit(factor=1e-15, master=meter*newton, name=...
#     femtojoule_base_unit = ScaledUnit(factor=1e-15, master=meter*newton, n...
#     femtojoules = Unit({ScaledUnit(factor=1e-15, master=meter*newton, name...
#     femtoliter = Unit({ScaledUnit(factor=1e-15, master=decimeter**3, name=...
#     femtoliter_base_unit = ScaledUnit(factor=1e-15, master=decimeter**3, n...
#     femtoliters = Unit({ScaledUnit(factor=1e-15, master=decimeter**3, name...
#     femtometer = Unit({BaseUnit(base_dim=BaseDimension("length"), name="fe...
#     femtometer_base_unit = BaseUnit(base_dim=BaseDimension("length"), name...
#     femtometers = Unit({BaseUnit(base_dim=BaseDimension("length"), name="f...
#     femtomolar = Unit({ScaledUnit(factor=1e-15, master=mole/liter, name='f...
#     femtomolar_base_unit = ScaledUnit(factor=1e-15, master=mole/liter, nam...
#     femtomolars = Unit({ScaledUnit(factor=1e-15, master=mole/liter, name='...
#     femtonewton = Unit({ScaledUnit(factor=1e-15, master=kilogram*m...cond*...
#     femtonewton_base_unit = ScaledUnit(factor=1e-15, master=kilogram*meter...
#     femtonewtons = Unit({ScaledUnit(factor=1e-15, master=kilogram*m...cond...
#     femtopascal = Unit({ScaledUnit(factor=1e-15, master=newton/(meter**2),...
#     femtopascal_base_unit = ScaledUnit(factor=1e-15, master=newton/(meter*...
#     femtopascals = Unit({ScaledUnit(factor=1e-15, master=newton/(meter**2)...
#     femtosecond = Unit({BaseUnit(base_dim=BaseDimension("time"), name="fem...
#     femtosecond_base_unit = BaseUnit(base_dim=BaseDimension("time"), name=...
#     femtoseconds = Unit({BaseUnit(base_dim=BaseDimension("time"), name="fe...
#     foot = Unit({BaseUnit(base_dim=BaseDimension("length"), name="foot", s...
#     foot_base_unit = BaseUnit(base_dim=BaseDimension("length"), name="foot...
#     fortnight = Unit({BaseUnit(base_dim=BaseDimension("time"), name="fortn...
#     fortnights = Unit({BaseUnit(base_dim=BaseDimension("time"), name="fort...
#     furlong = Unit({BaseUnit(base_dim=BaseDimension("length"), name="furlo...
#     furlongs = Unit({BaseUnit(base_dim=BaseDimension("length"), name="furl...
#     gauss = Unit({ScaledUnit(factor=0.0001, master=tesla, name='gauss', sy...
#     gauss_base_unit = ScaledUnit(factor=0.0001, master=tesla, name='gauss'...
#     gibi = <simtk.unit.prefix.SiPrefix object>
#     giga = <simtk.unit.prefix.SiPrefix object>
#     gigacalorie = Unit({ScaledUnit(factor=4184000000.0, master=joule, name...
#     gigacalorie_base_unit = ScaledUnit(factor=4184000000.0, master=joule, ...
#     gigacalories = Unit({ScaledUnit(factor=4184000000.0, master=joule, nam...
#     gigagram = Unit({BaseUnit(base_dim=BaseDimension("mass"), name="gigagr...
#     gigagram_base_unit = BaseUnit(base_dim=BaseDimension("mass"), name="gi...
#     gigagrams = Unit({BaseUnit(base_dim=BaseDimension("mass"), name="gigag...
#     gigajoule = Unit({ScaledUnit(factor=1000000000.0, master=meter*newton,...
#     gigajoule_base_unit = ScaledUnit(factor=1000000000.0, master=meter*new...
#     gigajoules = Unit({ScaledUnit(factor=1000000000.0, master=meter*newton...
#     gigaliter = Unit({ScaledUnit(factor=1000000000.0, master=decimeter**3,...
#     gigaliter_base_unit = ScaledUnit(factor=1000000000.0, master=decimeter...
#     gigaliters = Unit({ScaledUnit(factor=1000000000.0, master=decimeter**3...
#     gigameter = Unit({BaseUnit(base_dim=BaseDimension("length"), name="gig...
#     gigameter_base_unit = BaseUnit(base_dim=BaseDimension("length"), name=...
#     gigameters = Unit({BaseUnit(base_dim=BaseDimension("length"), name="gi...
#     gigamolar = Unit({ScaledUnit(factor=1000000000.0, master=mole/liter, n...
#     gigamolar_base_unit = ScaledUnit(factor=1000000000.0, master=mole/lite...
#     gigamolars = Unit({ScaledUnit(factor=1000000000.0, master=mole/liter, ...
#     giganewton = Unit({ScaledUnit(factor=1000000000.0, master=kil...econd*...
#     giganewton_base_unit = ScaledUnit(factor=1000000000.0, master=kilogram...
#     giganewtons = Unit({ScaledUnit(factor=1000000000.0, master=kil...econd...
#     gigapascal = Unit({ScaledUnit(factor=1000000000.0, master=new...eter**...
#     gigapascal_base_unit = ScaledUnit(factor=1000000000.0, master=newton/(...
#     gigapascals = Unit({ScaledUnit(factor=1000000000.0, master=new...eter*...
#     gigasecond = Unit({BaseUnit(base_dim=BaseDimension("time"), name="giga...
#     gigasecond_base_unit = BaseUnit(base_dim=BaseDimension("time"), name="...
#     gigaseconds = Unit({BaseUnit(base_dim=BaseDimension("time"), name="gig...
#     gram = Unit({BaseUnit(base_dim=BaseDimension("mass"), name="gram", sym...
#     gram_base_unit = BaseUnit(base_dim=BaseDimension("mass"), name="gram",...
#     grams = Unit({BaseUnit(base_dim=BaseDimension("mass"), name="gram", sy...
#     hartley = Unit({BaseUnit(base_dim=BaseDimension("information"), name="...
#     hartleys = Unit({BaseUnit(base_dim=BaseDimension("information"), name=...
#     hecto = <simtk.unit.prefix.SiPrefix object>
#     hectocalorie = Unit({ScaledUnit(factor=418.40000000000003, master=joul...
#     hectocalorie_base_unit = ScaledUnit(factor=418.40000000000003, master=...
#     hectocalories = Unit({ScaledUnit(factor=418.40000000000003, master=jou...
#     hectogram = Unit({BaseUnit(base_dim=BaseDimension("mass"), name="hecto...
#     hectogram_base_unit = BaseUnit(base_dim=BaseDimension("mass"), name="h...
#     hectograms = Unit({BaseUnit(base_dim=BaseDimension("mass"), name="hect...
#     hectojoule = Unit({ScaledUnit(factor=100.0, master=meter*newton, name=...
#     hectojoule_base_unit = ScaledUnit(factor=100.0, master=meter*newton, n...
#     hectojoules = Unit({ScaledUnit(factor=100.0, master=meter*newton, name...
#     hectoliter = Unit({ScaledUnit(factor=100.0, master=decimeter**3, name=...
#     hectoliter_base_unit = ScaledUnit(factor=100.0, master=decimeter**3, n...
#     hectoliters = Unit({ScaledUnit(factor=100.0, master=decimeter**3, name...
#     hectometer = Unit({BaseUnit(base_dim=BaseDimension("length"), name="he...
#     hectometer_base_unit = BaseUnit(base_dim=BaseDimension("length"), name...
#     hectometers = Unit({BaseUnit(base_dim=BaseDimension("length"), name="h...
#     hectomolar = Unit({ScaledUnit(factor=100.0, master=mole/liter, name='h...
#     hectomolar_base_unit = ScaledUnit(factor=100.0, master=mole/liter, nam...
#     hectomolars = Unit({ScaledUnit(factor=100.0, master=mole/liter, name='...
#     hectonewton = Unit({ScaledUnit(factor=100.0, master=kilogram*m...cond*...
#     hectonewton_base_unit = ScaledUnit(factor=100.0, master=kilogram*meter...
#     hectonewtons = Unit({ScaledUnit(factor=100.0, master=kilogram*m...cond...
#     hectopascal = Unit({ScaledUnit(factor=100.0, master=newton/(meter**2),...
#     hectopascal_base_unit = ScaledUnit(factor=100.0, master=newton/(meter*...
#     hectopascals = Unit({ScaledUnit(factor=100.0, master=newton/(meter**2)...
#     hectosecond = Unit({BaseUnit(base_dim=BaseDimension("time"), name="hec...
#     hectosecond_base_unit = BaseUnit(base_dim=BaseDimension("time"), name=...
#     hectoseconds = Unit({BaseUnit(base_dim=BaseDimension("time"), name="he...
#     henries = Unit({ScaledUnit(factor=1.0, master=second*volt/ampere, name...
#     henry = Unit({ScaledUnit(factor=1.0, master=second*volt/ampere, name='...
#     henry_base_unit = ScaledUnit(factor=1.0, master=second*volt/ampere, na...
#     henrys = Unit({ScaledUnit(factor=1.0, master=second*volt/ampere, name=...
#     hour = Unit({BaseUnit(base_dim=BaseDimension("time"), name="hour", sym...
#     hours = Unit({BaseUnit(base_dim=BaseDimension("time"), name="hour", sy...
#     inch = Unit({BaseUnit(base_dim=BaseDimension("length"), name="inch", s...
#     inch_base_unit = BaseUnit(base_dim=BaseDimension("length"), name="inch...
#     inches = Unit({BaseUnit(base_dim=BaseDimension("length"), name="inch",...
#     information_dimension = BaseDimension("information")
#     item = Unit({BaseUnit(base_dim=BaseDimension("amount"), name="item", s...
#     items = Unit({BaseUnit(base_dim=BaseDimension("amount"), name="item", ...
#     joule = Unit({ScaledUnit(factor=1.0, master=meter*newton, name='joule'...
#     joule_base_unit = ScaledUnit(factor=1.0, master=meter*newton, name='jo...
#     joules = Unit({ScaledUnit(factor=1.0, master=meter*newton, name='joule...
#     kelvin = Unit({BaseUnit(base_dim=BaseDimension("temperature"), name="k...
#     kelvin_base_unit = BaseUnit(base_dim=BaseDimension("temperature"), nam...
#     kelvins = Unit({BaseUnit(base_dim=BaseDimension("temperature"), name="...
#     kibi = <simtk.unit.prefix.SiPrefix object>
#     kilo = <simtk.unit.prefix.SiPrefix object>
#     kilocalorie = Unit({ScaledUnit(factor=4184.0, master=joule, name='kilo...
#     kilocalorie_base_unit = ScaledUnit(factor=4184.0, master=joule, name='...
#     kilocalorie_per_mole = Unit({ScaledUnit(factor=4.184, master=kilojoule...
#     kilocalories = Unit({ScaledUnit(factor=4184.0, master=joule, name='kil...
#     kilocalories_per_mole = Unit({ScaledUnit(factor=4.184, master=kilojoul...
#     kilogram = Unit({BaseUnit(base_dim=BaseDimension("mass"), name="kilogr...
#     kilogram_base_unit = BaseUnit(base_dim=BaseDimension("mass"), name="ki...
#     kilograms = Unit({BaseUnit(base_dim=BaseDimension("mass"), name="kilog...
#     kilojoule = Unit({ScaledUnit(factor=1000.0, master=meter*newton, name=...
#     kilojoule_base_unit = ScaledUnit(factor=1000.0, master=meter*newton, n...
#     kilojoule_per_mole = Unit({ScaledUnit(factor=1.0, master=gram*nanomet....
#     kilojoules = Unit({ScaledUnit(factor=1000.0, master=meter*newton, name...
#     kilojoules_per_mole = Unit({ScaledUnit(factor=1.0, master=gram*nanomet...
#     kiloliter = Unit({ScaledUnit(factor=1000.0, master=decimeter**3, name=...
#     kiloliter_base_unit = ScaledUnit(factor=1000.0, master=decimeter**3, n...
#     kiloliters = Unit({ScaledUnit(factor=1000.0, master=decimeter**3, name...
#     kilometer = Unit({BaseUnit(base_dim=BaseDimension("length"), name="kil...
#     kilometer_base_unit = BaseUnit(base_dim=BaseDimension("length"), name=...
#     kilometers = Unit({BaseUnit(base_dim=BaseDimension("length"), name="ki...
#     kilomolar = Unit({ScaledUnit(factor=1000.0, master=mole/liter, name='k...
#     kilomolar_base_unit = ScaledUnit(factor=1000.0, master=mole/liter, nam...
#     kilomolars = Unit({ScaledUnit(factor=1000.0, master=mole/liter, name='...
#     kilonewton = Unit({ScaledUnit(factor=1000.0, master=kilogram*...econd*...
#     kilonewton_base_unit = ScaledUnit(factor=1000.0, master=kilogram*meter...
#     kilonewtons = Unit({ScaledUnit(factor=1000.0, master=kilogram*...econd...
#     kilopascal = Unit({ScaledUnit(factor=1000.0, master=newton/(meter**2),...
#     kilopascal_base_unit = ScaledUnit(factor=1000.0, master=newton/(meter*...
#     kilopascals = Unit({ScaledUnit(factor=1000.0, master=newton/(meter**2)...
#     kilosecond = Unit({BaseUnit(base_dim=BaseDimension("time"), name="kilo...
#     kilosecond_base_unit = BaseUnit(base_dim=BaseDimension("time"), name="...
#     kiloseconds = Unit({BaseUnit(base_dim=BaseDimension("time"), name="kil...
#     length_dimension = BaseDimension("length")
#     liter = Unit({ScaledUnit(factor=1.0, master=decimeter**3, name='liter'...
#     liter_base_unit = ScaledUnit(factor=1.0, master=decimeter**3, name='li...
#     liters = Unit({ScaledUnit(factor=1.0, master=decimeter**3, name='liter...
#     litre = Unit({ScaledUnit(factor=1.0, master=decimeter**3, name='liter'...
#     litres = Unit({ScaledUnit(factor=1.0, master=decimeter**3, name='liter...
#     luminous_intensity_dimension = BaseDimension("luminous intensity")
#     mass_dimension = BaseDimension("mass")
#     md_kilocalorie = Unit({ScaledUnit(factor=4.184, master=kilojoule, name...
#     md_kilocalories = Unit({ScaledUnit(factor=4.184, master=kilojoule, nam...
#     md_kilojoule = Unit({ScaledUnit(factor=1.0, master=gram*nanomet...seco...
#     md_kilojoule_raw = Unit({BaseUnit(base_dim=BaseDimension("length"),......
#     md_kilojoules = Unit({ScaledUnit(factor=1.0, master=gram*nanomet...sec...
#     md_unit_system = <simtk.unit.unit.UnitSystem object>
#     mebi = <simtk.unit.prefix.SiPrefix object>
#     mega = <simtk.unit.prefix.SiPrefix object>
#     megacalorie = Unit({ScaledUnit(factor=4184000.0, master=joule, name='m...
#     megacalorie_base_unit = ScaledUnit(factor=4184000.0, master=joule, nam...
#     megacalories = Unit({ScaledUnit(factor=4184000.0, master=joule, name='...
#     megagram = Unit({BaseUnit(base_dim=BaseDimension("mass"), name="megagr...
#     megagram_base_unit = BaseUnit(base_dim=BaseDimension("mass"), name="me...
#     megagrams = Unit({BaseUnit(base_dim=BaseDimension("mass"), name="megag...
#     megajoule = Unit({ScaledUnit(factor=1000000.0, master=meter*newton, na...
#     megajoule_base_unit = ScaledUnit(factor=1000000.0, master=meter*newton...
#     megajoules = Unit({ScaledUnit(factor=1000000.0, master=meter*newton, n...
#     megaliter = Unit({ScaledUnit(factor=1000000.0, master=decimeter**3, na...
#     megaliter_base_unit = ScaledUnit(factor=1000000.0, master=decimeter**3...
#     megaliters = Unit({ScaledUnit(factor=1000000.0, master=decimeter**3, n...
#     megameter = Unit({BaseUnit(base_dim=BaseDimension("length"), name="meg...
#     megameter_base_unit = BaseUnit(base_dim=BaseDimension("length"), name=...
#     megameters = Unit({BaseUnit(base_dim=BaseDimension("length"), name="me...
#     megamolar = Unit({ScaledUnit(factor=1000000.0, master=mole/liter, name...
#     megamolar_base_unit = ScaledUnit(factor=1000000.0, master=mole/liter, ...
#     megamolars = Unit({ScaledUnit(factor=1000000.0, master=mole/liter, nam...
#     meganewton = Unit({ScaledUnit(factor=1000000.0, master=kilogr...econd*...
#     meganewton_base_unit = ScaledUnit(factor=1000000.0, master=kilogram*me...
#     meganewtons = Unit({ScaledUnit(factor=1000000.0, master=kilogr...econd...
#     megapascal = Unit({ScaledUnit(factor=1000000.0, master=newton/(meter**...
#     megapascal_base_unit = ScaledUnit(factor=1000000.0, master=newton/(met...
#     megapascals = Unit({ScaledUnit(factor=1000000.0, master=newton/(meter*...
#     megasecond = Unit({BaseUnit(base_dim=BaseDimension("time"), name="mega...
#     megasecond_base_unit = BaseUnit(base_dim=BaseDimension("time"), name="...
#     megaseconds = Unit({BaseUnit(base_dim=BaseDimension("time"), name="meg...
#     meter = Unit({BaseUnit(base_dim=BaseDimension("length"), name="meter",...
#     meter_base_unit = BaseUnit(base_dim=BaseDimension("length"), name="met...
#     meters = Unit({BaseUnit(base_dim=BaseDimension("length"), name="meter"...
#     micro = <simtk.unit.prefix.SiPrefix object>
#     microcalorie = Unit({ScaledUnit(factor=4.184e-06, master=joule, name='...
#     microcalorie_base_unit = ScaledUnit(factor=4.184e-06, master=joule, na...
#     microcalories = Unit({ScaledUnit(factor=4.184e-06, master=joule, name=...
#     microgram = Unit({BaseUnit(base_dim=BaseDimension("mass"), name="micro...
#     microgram_base_unit = BaseUnit(base_dim=BaseDimension("mass"), name="m...
#     micrograms = Unit({BaseUnit(base_dim=BaseDimension("mass"), name="micr...
#     microjoule = Unit({ScaledUnit(factor=1e-06, master=meter*newton, name=...
#     microjoule_base_unit = ScaledUnit(factor=1e-06, master=meter*newton, n...
#     microjoules = Unit({ScaledUnit(factor=1e-06, master=meter*newton, name...
#     microliter = Unit({ScaledUnit(factor=1e-06, master=decimeter**3, name=...
#     microliter_base_unit = ScaledUnit(factor=1e-06, master=decimeter**3, n...
#     microliters = Unit({ScaledUnit(factor=1e-06, master=decimeter**3, name...
#     micrometer = Unit({BaseUnit(base_dim=BaseDimension("length"), name="mi...
#     micrometer_base_unit = BaseUnit(base_dim=BaseDimension("length"), name...
#     micrometers = Unit({BaseUnit(base_dim=BaseDimension("length"), name="m...
#     micromolar = Unit({ScaledUnit(factor=1e-06, master=mole/liter, name='m...
#     micromolar_base_unit = ScaledUnit(factor=1e-06, master=mole/liter, nam...
#     micromolars = Unit({ScaledUnit(factor=1e-06, master=mole/liter, name='...
#     micronewton = Unit({ScaledUnit(factor=1e-06, master=kilogram*m...cond*...
#     micronewton_base_unit = ScaledUnit(factor=1e-06, master=kilogram*meter...
#     micronewtons = Unit({ScaledUnit(factor=1e-06, master=kilogram*m...cond...
#     micropascal = Unit({ScaledUnit(factor=1e-06, master=newton/(meter**2),...
#     micropascal_base_unit = ScaledUnit(factor=1e-06, master=newton/(meter*...
#     micropascals = Unit({ScaledUnit(factor=1e-06, master=newton/(meter**2)...
#     microsecond = Unit({BaseUnit(base_dim=BaseDimension("time"), name="mic...
#     microsecond_base_unit = BaseUnit(base_dim=BaseDimension("time"), name=...
#     microseconds = Unit({BaseUnit(base_dim=BaseDimension("time"), name="mi...
#     mile = Unit({BaseUnit(base_dim=BaseDimension("length"), name="mile", s...
#     miles = Unit({BaseUnit(base_dim=BaseDimension("length"), name="mile", ...
#     millenia = Unit({BaseUnit(base_dim=BaseDimension("time"), name="millen...
#     millenium = Unit({BaseUnit(base_dim=BaseDimension("time"), name="mille...
#     milleniums = Unit({BaseUnit(base_dim=BaseDimension("time"), name="mill...
#     milli = <simtk.unit.prefix.SiPrefix object>
#     millicalorie = Unit({ScaledUnit(factor=0.004184, master=joule, name='m...
#     millicalorie_base_unit = ScaledUnit(factor=0.004184, master=joule, nam...
#     millicalories = Unit({ScaledUnit(factor=0.004184, master=joule, name='...
#     milligram = Unit({BaseUnit(base_dim=BaseDimension("mass"), name="milli...
#     milligram_base_unit = BaseUnit(base_dim=BaseDimension("mass"), name="m...
#     milligrams = Unit({BaseUnit(base_dim=BaseDimension("mass"), name="mill...
#     millijoule = Unit({ScaledUnit(factor=0.001, master=meter*newton, name=...
#     millijoule_base_unit = ScaledUnit(factor=0.001, master=meter*newton, n...
#     millijoules = Unit({ScaledUnit(factor=0.001, master=meter*newton, name...
#     milliliter = Unit({ScaledUnit(factor=0.001, master=decimeter**3, name=...
#     milliliter_base_unit = ScaledUnit(factor=0.001, master=decimeter**3, n...
#     milliliters = Unit({ScaledUnit(factor=0.001, master=decimeter**3, name...
#     millimeter = Unit({BaseUnit(base_dim=BaseDimension("length"), name="mi...
#     millimeter_base_unit = BaseUnit(base_dim=BaseDimension("length"), name...
#     millimeters = Unit({BaseUnit(base_dim=BaseDimension("length"), name="m...
#     millimolar = Unit({ScaledUnit(factor=0.001, master=mole/liter, name='m...
#     millimolar_base_unit = ScaledUnit(factor=0.001, master=mole/liter, nam...
#     millimolars = Unit({ScaledUnit(factor=0.001, master=mole/liter, name='...
#     millinewton = Unit({ScaledUnit(factor=0.001, master=kilogram*m...cond*...
#     millinewton_base_unit = ScaledUnit(factor=0.001, master=kilogram*meter...
#     millinewtons = Unit({ScaledUnit(factor=0.001, master=kilogram*m...cond...
#     millipascal = Unit({ScaledUnit(factor=0.001, master=newton/(meter**2),...
#     millipascal_base_unit = ScaledUnit(factor=0.001, master=newton/(meter*...
#     millipascals = Unit({ScaledUnit(factor=0.001, master=newton/(meter**2)...
#     millisecond = Unit({BaseUnit(base_dim=BaseDimension("time"), name="mil...
#     millisecond_base_unit = BaseUnit(base_dim=BaseDimension("time"), name=...
#     milliseconds = Unit({BaseUnit(base_dim=BaseDimension("time"), name="mi...
#     minute = Unit({BaseUnit(base_dim=BaseDimension("time"), name="minute",...
#     minutes = Unit({BaseUnit(base_dim=BaseDimension("time"), name="minute"...
#     mmHg = Unit({ScaledUnit(factor=133.322, master=pascal, name='mmHg', sy...
#     mmHg_base_unit = ScaledUnit(factor=133.322, master=pascal, name='mmHg'...
#     molal = Unit({ScaledUnit(factor=1.0, master=mole/liter, name='molar', ...
#     molar = Unit({ScaledUnit(factor=1.0, master=mole/liter, name='molar', ...
#     molar_base_unit = ScaledUnit(factor=1.0, master=mole/liter, name='mola...
#     mole = Unit({BaseUnit(base_dim=BaseDimension("amount"), name="mole", s...
#     mole_base_unit = BaseUnit(base_dim=BaseDimension("amount"), name="mole...
#     moles = Unit({BaseUnit(base_dim=BaseDimension("amount"), name="mole", ...
#     nano = <simtk.unit.prefix.SiPrefix object>
#     nanocalorie = Unit({ScaledUnit(factor=4.1840000000000004e-09, ...=joul...
#     nanocalorie_base_unit = ScaledUnit(factor=4.1840000000000004e-09, mast...
#     nanocalories = Unit({ScaledUnit(factor=4.1840000000000004e-09, ...=jou...
#     nanogram = Unit({BaseUnit(base_dim=BaseDimension("mass"), name="nanogr...
#     nanogram_base_unit = BaseUnit(base_dim=BaseDimension("mass"), name="na...
#     nanograms = Unit({BaseUnit(base_dim=BaseDimension("mass"), name="nanog...
#     nanojoule = Unit({ScaledUnit(factor=1e-09, master=meter*newton, name='...
#     nanojoule_base_unit = ScaledUnit(factor=1e-09, master=meter*newton, na...
#     nanojoules = Unit({ScaledUnit(factor=1e-09, master=meter*newton, name=...
#     nanoliter = Unit({ScaledUnit(factor=1e-09, master=decimeter**3, name='...
#     nanoliter_base_unit = ScaledUnit(factor=1e-09, master=decimeter**3, na...
#     nanoliters = Unit({ScaledUnit(factor=1e-09, master=decimeter**3, name=...
#     nanometer = Unit({BaseUnit(base_dim=BaseDimension("length"), name="nan...
#     nanometer_base_unit = BaseUnit(base_dim=BaseDimension("length"), name=...
#     nanometers = Unit({BaseUnit(base_dim=BaseDimension("length"), name="na...
#     nanomolar = Unit({ScaledUnit(factor=1e-09, master=mole/liter, name='na...
#     nanomolar_base_unit = ScaledUnit(factor=1e-09, master=mole/liter, name...
#     nanomolars = Unit({ScaledUnit(factor=1e-09, master=mole/liter, name='n...
#     nanonewton = Unit({ScaledUnit(factor=1e-09, master=kilogram*m...econd*...
#     nanonewton_base_unit = ScaledUnit(factor=1e-09, master=kilogram*meter/...
#     nanonewtons = Unit({ScaledUnit(factor=1e-09, master=kilogram*m...econd...
#     nanopascal = Unit({ScaledUnit(factor=1e-09, master=newton/(meter**2), ...
#     nanopascal_base_unit = ScaledUnit(factor=1e-09, master=newton/(meter**...
#     nanopascals = Unit({ScaledUnit(factor=1e-09, master=newton/(meter**2),...
#     nanosecond = Unit({BaseUnit(base_dim=BaseDimension("time"), name="nano...
#     nanosecond_base_unit = BaseUnit(base_dim=BaseDimension("time"), name="...
#     nanoseconds = Unit({BaseUnit(base_dim=BaseDimension("time"), name="nan...
#     nat = Unit({BaseUnit(base_dim=BaseDimension("information"), name="nat"...
#     nat_base_unit = BaseUnit(base_dim=BaseDimension("information"), name="...
#     nats = Unit({BaseUnit(base_dim=BaseDimension("information"), name="nat...
#     nepit = Unit({BaseUnit(base_dim=BaseDimension("information"), name="na...
#     nepits = Unit({BaseUnit(base_dim=BaseDimension("information"), name="n...
#     newton = Unit({ScaledUnit(factor=1.0, master=kilogram*meter/(second**2...
#     newton_base_unit = ScaledUnit(factor=1.0, master=kilogram*meter/(secon...
#     newtons = Unit({ScaledUnit(factor=1.0, master=kilogram*meter/(second**...
#     nit = Unit({BaseUnit(base_dim=BaseDimension("information"), name="nat"...
#     nits = Unit({BaseUnit(base_dim=BaseDimension("information"), name="nat...
#     ohm = Unit({ScaledUnit(factor=1.0, master=volt/ampere, name='ohm', sym...
#     ohm_base_unit = ScaledUnit(factor=1.0, master=volt/ampere, name='ohm',...
#     ohms = Unit({ScaledUnit(factor=1.0, master=volt/ampere, name='ohm', sy...
#     pascal = Unit({ScaledUnit(factor=1.0, master=newton/(meter**2), name='...
#     pascal_base_unit = ScaledUnit(factor=1.0, master=newton/(meter**2), na...
#     pascals = Unit({ScaledUnit(factor=1.0, master=newton/(meter**2), name=...
#     pebi = <simtk.unit.prefix.SiPrefix object>
#     peta = <simtk.unit.prefix.SiPrefix object>
#     petacalorie = Unit({ScaledUnit(factor=4184000000000000.0, master=joule...
#     petacalorie_base_unit = ScaledUnit(factor=4184000000000000.0, master=j...
#     petacalories = Unit({ScaledUnit(factor=4184000000000000.0, master=joul...
#     petagram = Unit({BaseUnit(base_dim=BaseDimension("mass"), name="petagr...
#     petagram_base_unit = BaseUnit(base_dim=BaseDimension("mass"), name="pe...
#     petagrams = Unit({BaseUnit(base_dim=BaseDimension("mass"), name="petag...
#     petajoule = Unit({ScaledUnit(factor=1000000000000000.0, mast...ter*new...
#     petajoule_base_unit = ScaledUnit(factor=1000000000000000.0, master=met...
#     petajoules = Unit({ScaledUnit(factor=1000000000000000.0, mast...ter*ne...
#     petaliter = Unit({ScaledUnit(factor=1000000000000000.0, mast...cimeter...
#     petaliter_base_unit = ScaledUnit(factor=1000000000000000.0, master=dec...
#     petaliters = Unit({ScaledUnit(factor=1000000000000000.0, mast...cimete...
#     petameter = Unit({BaseUnit(base_dim=BaseDimension("length"), name="pet...
#     petameter_base_unit = BaseUnit(base_dim=BaseDimension("length"), name=...
#     petameters = Unit({BaseUnit(base_dim=BaseDimension("length"), name="pe...
#     petamolar = Unit({ScaledUnit(factor=1000000000000000.0, master=mole/li...
#     petamolar_base_unit = ScaledUnit(factor=1000000000000000.0, master=mol...
#     petamolars = Unit({ScaledUnit(factor=1000000000000000.0, master=mole/l...
#     petanewton = Unit({ScaledUnit(factor=1000000000000000.0, mast...econd*...
#     petanewton_base_unit = ScaledUnit(factor=1000000000000000.0, master=ki...
#     petanewtons = Unit({ScaledUnit(factor=1000000000000000.0, mast...econd...
#     petapascal = Unit({ScaledUnit(factor=1000000000000000.0, mast...eter**...
#     petapascal_base_unit = ScaledUnit(factor=1000000000000000.0, master=ne...
#     petapascals = Unit({ScaledUnit(factor=1000000000000000.0, mast...eter*...
#     petasecond = Unit({BaseUnit(base_dim=BaseDimension("time"), name="peta...
#     petasecond_base_unit = BaseUnit(base_dim=BaseDimension("time"), name="...
#     petaseconds = Unit({BaseUnit(base_dim=BaseDimension("time"), name="pet...
#     pico = <simtk.unit.prefix.SiPrefix object>
#     picocalorie = Unit({ScaledUnit(factor=4.184e-12, master=joule, name='p...
#     picocalorie_base_unit = ScaledUnit(factor=4.184e-12, master=joule, nam...
#     picocalories = Unit({ScaledUnit(factor=4.184e-12, master=joule, name='...
#     picogram = Unit({BaseUnit(base_dim=BaseDimension("mass"), name="picogr...
#     picogram_base_unit = BaseUnit(base_dim=BaseDimension("mass"), name="pi...
#     picograms = Unit({BaseUnit(base_dim=BaseDimension("mass"), name="picog...
#     picojoule = Unit({ScaledUnit(factor=1e-12, master=meter*newton, name='...
#     picojoule_base_unit = ScaledUnit(factor=1e-12, master=meter*newton, na...
#     picojoules = Unit({ScaledUnit(factor=1e-12, master=meter*newton, name=...
#     picoliter = Unit({ScaledUnit(factor=1e-12, master=decimeter**3, name='...
#     picoliter_base_unit = ScaledUnit(factor=1e-12, master=decimeter**3, na...
#     picoliters = Unit({ScaledUnit(factor=1e-12, master=decimeter**3, name=...
#     picometer = Unit({BaseUnit(base_dim=BaseDimension("length"), name="pic...
#     picometer_base_unit = BaseUnit(base_dim=BaseDimension("length"), name=...
#     picometers = Unit({BaseUnit(base_dim=BaseDimension("length"), name="pi...
#     picomolar = Unit({ScaledUnit(factor=1e-12, master=mole/liter, name='pi...
#     picomolar_base_unit = ScaledUnit(factor=1e-12, master=mole/liter, name...
#     picomolars = Unit({ScaledUnit(factor=1e-12, master=mole/liter, name='p...
#     piconewton = Unit({ScaledUnit(factor=1e-12, master=kilogram*m...econd*...
#     piconewton_base_unit = ScaledUnit(factor=1e-12, master=kilogram*meter/...
#     piconewtons = Unit({ScaledUnit(factor=1e-12, master=kilogram*m...econd...
#     picopascal = Unit({ScaledUnit(factor=1e-12, master=newton/(meter**2), ...
#     picopascal_base_unit = ScaledUnit(factor=1e-12, master=newton/(meter**...
#     picopascals = Unit({ScaledUnit(factor=1e-12, master=newton/(meter**2),...
#     picosecond = Unit({BaseUnit(base_dim=BaseDimension("time"), name="pico...
#     picosecond_base_unit = BaseUnit(base_dim=BaseDimension("time"), name="...
#     picoseconds = Unit({BaseUnit(base_dim=BaseDimension("time"), name="pic...
#     planck_charge_base_unit = BaseUnit(base_dim=BaseDimension("charge"), n...
#     planck_length_base_unit = BaseUnit(base_dim=BaseDimension("length"), n...
#     planck_mass_base_unit = BaseUnit(base_dim=BaseDimension("mass"), name=...
#     planck_temperature_base_unit = BaseUnit(base_dim=BaseDimension("temper...
#     planck_time_base_unit = BaseUnit(base_dim=BaseDimension("time"), name=...
#     planck_unit_system = <simtk.unit.unit.UnitSystem object>
#     pound_force = Unit({ScaledUnit(factor=4.448, master=newton, name='poun...
#     pound_force_base_unit = ScaledUnit(factor=4.448, master=newton, name='...
#     pound_mass = Unit({BaseUnit(base_dim=BaseDimension("mass"), name="poun...
#     pound_mass_base_unit = BaseUnit(base_dim=BaseDimension("mass"), name="...
#     pounds_force = Unit({ScaledUnit(factor=4.448, master=newton, name='pou...
#     pounds_mass = Unit({BaseUnit(base_dim=BaseDimension("mass"), name="pou...
#     print_function = _Feature((2, 6, 0, 'alpha', 2), (3, 0, 0, 'alpha', 0)...
#     psi = Unit({ScaledUnit(factor=0.11297920000000002, mas...pound/(inch**...
#     psi_base_unit = ScaledUnit(factor=0.11297920000000002, master=pound/(i...
#     radian = Unit({BaseUnit(base_dim=BaseDimension("angle"), name="radian"...
#     radian_base_unit = BaseUnit(base_dim=BaseDimension("angle"), name="rad...
#     radians = Unit({BaseUnit(base_dim=BaseDimension("angle"), name="radian...
#     second = Unit({BaseUnit(base_dim=BaseDimension("time"), name="second",...
#     second_base_unit = BaseUnit(base_dim=BaseDimension("time"), name="seco...
#     seconds = Unit({BaseUnit(base_dim=BaseDimension("time"), name="second"...
#     si_prefixes = (<simtk.unit.prefix.SiPrefix object>, <simtk.unit.prefix...
#     si_unit_system = <simtk.unit.unit.UnitSystem object>
#     single_item_amount_base_unit = BaseUnit(base_dim=BaseDimension("amount...
#     stone = Unit({BaseUnit(base_dim=BaseDimension("mass"), name="stone", s...
#     stone_base_unit = BaseUnit(base_dim=BaseDimension("mass"), name="stone...
#     stones = Unit({BaseUnit(base_dim=BaseDimension("mass"), name="stone", ...
#     tebi = <simtk.unit.prefix.SiPrefix object>
#     temperature_dimension = BaseDimension("temperature")
#     tera = <simtk.unit.prefix.SiPrefix object>
#     teracalorie = Unit({ScaledUnit(factor=4184000000000.0, master=joule, n...
#     teracalorie_base_unit = ScaledUnit(factor=4184000000000.0, master=joul...
#     teracalories = Unit({ScaledUnit(factor=4184000000000.0, master=joule, ...
#     teragram = Unit({BaseUnit(base_dim=BaseDimension("mass"), name="teragr...
#     teragram_base_unit = BaseUnit(base_dim=BaseDimension("mass"), name="te...
#     teragrams = Unit({BaseUnit(base_dim=BaseDimension("mass"), name="terag...
#     terajoule = Unit({ScaledUnit(factor=1000000000000.0, master=meter*newt...
#     terajoule_base_unit = ScaledUnit(factor=1000000000000.0, master=meter*...
#     terajoules = Unit({ScaledUnit(factor=1000000000000.0, master=meter*new...
#     teraliter = Unit({ScaledUnit(factor=1000000000000.0, master=decimeter*...
#     teraliter_base_unit = ScaledUnit(factor=1000000000000.0, master=decime...
#     teraliters = Unit({ScaledUnit(factor=1000000000000.0, master=decimeter...
#     terameter = Unit({BaseUnit(base_dim=BaseDimension("length"), name="ter...
#     terameter_base_unit = BaseUnit(base_dim=BaseDimension("length"), name=...
#     terameters = Unit({BaseUnit(base_dim=BaseDimension("length"), name="te...
#     teramolar = Unit({ScaledUnit(factor=1000000000000.0, master=mole/liter...
#     teramolar_base_unit = ScaledUnit(factor=1000000000000.0, master=mole/l...
#     teramolars = Unit({ScaledUnit(factor=1000000000000.0, master=mole/lite...
#     teranewton = Unit({ScaledUnit(factor=1000000000000.0, master=...econd*...
#     teranewton_base_unit = ScaledUnit(factor=1000000000000.0, master=kilog...
#     teranewtons = Unit({ScaledUnit(factor=1000000000000.0, master=...econd...
#     terapascal = Unit({ScaledUnit(factor=1000000000000.0, master=...eter**...
#     terapascal_base_unit = ScaledUnit(factor=1000000000000.0, master=newto...
#     terapascals = Unit({ScaledUnit(factor=1000000000000.0, master=...eter*...
#     terasecond = Unit({BaseUnit(base_dim=BaseDimension("time"), name="tera...
#     terasecond_base_unit = BaseUnit(base_dim=BaseDimension("time"), name="...
#     teraseconds = Unit({BaseUnit(base_dim=BaseDimension("time"), name="ter...
#     tesla = Unit({ScaledUnit(factor=1.0, master=newton/(meter*ampere), nam...
#     tesla_base_unit = ScaledUnit(factor=1.0, master=newton/(meter*ampere),...
#     teslas = Unit({ScaledUnit(factor=1.0, master=newton/(meter*ampere), na...
#     time_dimension = BaseDimension("time")
#     torr = Unit({ScaledUnit(factor=133.32236842105263, master=atmosphere, ...
#     torr_base_unit = ScaledUnit(factor=133.32236842105263, master=atmosphe...
#     volt = Unit({ScaledUnit(factor=1.0, master=watt/ampere, name='volt', s...
#     volt_base_unit = ScaledUnit(factor=1.0, master=watt/ampere, name='volt...
#     volts = Unit({ScaledUnit(factor=1.0, master=watt/ampere, name='volt', ...
#     watt = Unit({ScaledUnit(factor=1.0, master=joule/second, name='watt', ...
#     watt_base_unit = ScaledUnit(factor=1.0, master=joule/second, name='wat...
#     watts = Unit({ScaledUnit(factor=1.0, master=joule/second, name='watt',...
#     week = Unit({BaseUnit(base_dim=BaseDimension("time"), name="week", sym...
#     weeks = Unit({BaseUnit(base_dim=BaseDimension("time"), name="week", sy...
#     yard = Unit({BaseUnit(base_dim=BaseDimension("length"), name="yard", s...
#     yard_base_unit = BaseUnit(base_dim=BaseDimension("length"), name="yard...
#     yards = Unit({BaseUnit(base_dim=BaseDimension("length"), name="yard", ...
#     year = Unit({BaseUnit(base_dim=BaseDimension("time"), name="julian yea...
#     years = Unit({BaseUnit(base_dim=BaseDimension("time"), name="julian ye...
#     yobi = <simtk.unit.prefix.SiPrefix object>
#     yotta = <simtk.unit.prefix.SiPrefix object>
#     yottacalorie = Unit({ScaledUnit(factor=4.184e+24, master=joule, name='...
#     yottacalorie_base_unit = ScaledUnit(factor=4.184e+24, master=joule, na...
#     yottacalories = Unit({ScaledUnit(factor=4.184e+24, master=joule, name=...
#     yottagram = Unit({BaseUnit(base_dim=BaseDimension("mass"), name="yotta...
#     yottagram_base_unit = BaseUnit(base_dim=BaseDimension("mass"), name="y...
#     yottagrams = Unit({BaseUnit(base_dim=BaseDimension("mass"), name="yott...
#     yottajoule = Unit({ScaledUnit(factor=1e+24, master=meter*newton, name=...
#     yottajoule_base_unit = ScaledUnit(factor=1e+24, master=meter*newton, n...
#     yottajoules = Unit({ScaledUnit(factor=1e+24, master=meter*newton, name...
#     yottaliter = Unit({ScaledUnit(factor=1e+24, master=decimeter**3, name=...
#     yottaliter_base_unit = ScaledUnit(factor=1e+24, master=decimeter**3, n...
#     yottaliters = Unit({ScaledUnit(factor=1e+24, master=decimeter**3, name...
#     yottameter = Unit({BaseUnit(base_dim=BaseDimension("length"), name="yo...
#     yottameter_base_unit = BaseUnit(base_dim=BaseDimension("length"), name...
#     yottameters = Unit({BaseUnit(base_dim=BaseDimension("length"), name="y...
#     yottamolar = Unit({ScaledUnit(factor=1e+24, master=mole/liter, name='y...
#     yottamolar_base_unit = ScaledUnit(factor=1e+24, master=mole/liter, nam...
#     yottamolars = Unit({ScaledUnit(factor=1e+24, master=mole/liter, name='...
#     yottanewton = Unit({ScaledUnit(factor=1e+24, master=kilogram*m...cond*...
#     yottanewton_base_unit = ScaledUnit(factor=1e+24, master=kilogram*meter...
#     yottanewtons = Unit({ScaledUnit(factor=1e+24, master=kilogram*m...cond...
#     yottapascal = Unit({ScaledUnit(factor=1e+24, master=newton/(meter**2),...
#     yottapascal_base_unit = ScaledUnit(factor=1e+24, master=newton/(meter*...
#     yottapascals = Unit({ScaledUnit(factor=1e+24, master=newton/(meter**2)...
#     yottasecond = Unit({BaseUnit(base_dim=BaseDimension("time"), name="yot...
#     yottasecond_base_unit = BaseUnit(base_dim=BaseDimension("time"), name=...
#     yottaseconds = Unit({BaseUnit(base_dim=BaseDimension("time"), name="yo...
#     yotto = <simtk.unit.prefix.SiPrefix object>
#     yottocalorie = Unit({ScaledUnit(factor=4.184e-24, master=joule, name='...
#     yottocalorie_base_unit = ScaledUnit(factor=4.184e-24, master=joule, na...
#     yottocalories = Unit({ScaledUnit(factor=4.184e-24, master=joule, name=...
#     yottogram = Unit({BaseUnit(base_dim=BaseDimension("mass"), name="yotto...
#     yottogram_base_unit = BaseUnit(base_dim=BaseDimension("mass"), name="y...
#     yottograms = Unit({BaseUnit(base_dim=BaseDimension("mass"), name="yott...
#     yottojoule = Unit({ScaledUnit(factor=1e-24, master=meter*newton, name=...
#     yottojoule_base_unit = ScaledUnit(factor=1e-24, master=meter*newton, n...
#     yottojoules = Unit({ScaledUnit(factor=1e-24, master=meter*newton, name...
#     yottoliter = Unit({ScaledUnit(factor=1e-24, master=decimeter**3, name=...
#     yottoliter_base_unit = ScaledUnit(factor=1e-24, master=decimeter**3, n...
#     yottoliters = Unit({ScaledUnit(factor=1e-24, master=decimeter**3, name...
#     yottometer = Unit({BaseUnit(base_dim=BaseDimension("length"), name="yo...
#     yottometer_base_unit = BaseUnit(base_dim=BaseDimension("length"), name...
#     yottometers = Unit({BaseUnit(base_dim=BaseDimension("length"), name="y...
#     yottomolar = Unit({ScaledUnit(factor=1e-24, master=mole/liter, name='y...
#     yottomolar_base_unit = ScaledUnit(factor=1e-24, master=mole/liter, nam...
#     yottomolars = Unit({ScaledUnit(factor=1e-24, master=mole/liter, name='...
#     yottonewton = Unit({ScaledUnit(factor=1e-24, master=kilogram*m...cond*...
#     yottonewton_base_unit = ScaledUnit(factor=1e-24, master=kilogram*meter...
#     yottonewtons = Unit({ScaledUnit(factor=1e-24, master=kilogram*m...cond...
#     yottopascal = Unit({ScaledUnit(factor=1e-24, master=newton/(meter**2),...
#     yottopascal_base_unit = ScaledUnit(factor=1e-24, master=newton/(meter*...
#     yottopascals = Unit({ScaledUnit(factor=1e-24, master=newton/(meter**2)...
#     yottosecond = Unit({BaseUnit(base_dim=BaseDimension("time"), name="yot...
#     yottosecond_base_unit = BaseUnit(base_dim=BaseDimension("time"), name=...
#     yottoseconds = Unit({BaseUnit(base_dim=BaseDimension("time"), name="yo...
#     zebi = <simtk.unit.prefix.SiPrefix object>
#     zepto = <simtk.unit.prefix.SiPrefix object>
#     zeptocalorie = Unit({ScaledUnit(factor=4.184e-21, master=joule, name='...
#     zeptocalorie_base_unit = ScaledUnit(factor=4.184e-21, master=joule, na...
#     zeptocalories = Unit({ScaledUnit(factor=4.184e-21, master=joule, name=...
#     zeptogram = Unit({BaseUnit(base_dim=BaseDimension("mass"), name="zepto...
#     zeptogram_base_unit = BaseUnit(base_dim=BaseDimension("mass"), name="z...
#     zeptograms = Unit({BaseUnit(base_dim=BaseDimension("mass"), name="zept...
#     zeptojoule = Unit({ScaledUnit(factor=1e-21, master=meter*newton, name=...
#     zeptojoule_base_unit = ScaledUnit(factor=1e-21, master=meter*newton, n...
#     zeptojoules = Unit({ScaledUnit(factor=1e-21, master=meter*newton, name...
#     zeptoliter = Unit({ScaledUnit(factor=1e-21, master=decimeter**3, name=...
#     zeptoliter_base_unit = ScaledUnit(factor=1e-21, master=decimeter**3, n...
#     zeptoliters = Unit({ScaledUnit(factor=1e-21, master=decimeter**3, name...
#     zeptometer = Unit({BaseUnit(base_dim=BaseDimension("length"), name="ze...
#     zeptometer_base_unit = BaseUnit(base_dim=BaseDimension("length"), name...
#     zeptometers = Unit({BaseUnit(base_dim=BaseDimension("length"), name="z...
#     zeptomolar = Unit({ScaledUnit(factor=1e-21, master=mole/liter, name='z...
#     zeptomolar_base_unit = ScaledUnit(factor=1e-21, master=mole/liter, nam...
#     zeptomolars = Unit({ScaledUnit(factor=1e-21, master=mole/liter, name='...
#     zeptonewton = Unit({ScaledUnit(factor=1e-21, master=kilogram*m...cond*...
#     zeptonewton_base_unit = ScaledUnit(factor=1e-21, master=kilogram*meter...
#     zeptonewtons = Unit({ScaledUnit(factor=1e-21, master=kilogram*m...cond...
#     zeptopascal = Unit({ScaledUnit(factor=1e-21, master=newton/(meter**2),...
#     zeptopascal_base_unit = ScaledUnit(factor=1e-21, master=newton/(meter*...
#     zeptopascals = Unit({ScaledUnit(factor=1e-21, master=newton/(meter**2)...
#     zeptosecond = Unit({BaseUnit(base_dim=BaseDimension("time"), name="zep...
#     zeptosecond_base_unit = BaseUnit(base_dim=BaseDimension("time"), name=...
#     zeptoseconds = Unit({BaseUnit(base_dim=BaseDimension("time"), name="ze...
#     zetta = <simtk.unit.prefix.SiPrefix object>
#     zettacalorie = Unit({ScaledUnit(factor=4.184e+21, master=joule, name='...
#     zettacalorie_base_unit = ScaledUnit(factor=4.184e+21, master=joule, na...
#     zettacalories = Unit({ScaledUnit(factor=4.184e+21, master=joule, name=...
#     zettagram = Unit({BaseUnit(base_dim=BaseDimension("mass"), name="zetta...
#     zettagram_base_unit = BaseUnit(base_dim=BaseDimension("mass"), name="z...
#     zettagrams = Unit({BaseUnit(base_dim=BaseDimension("mass"), name="zett...
#     zettajoule = Unit({ScaledUnit(factor=1e+21, master=meter*newton, name=...
#     zettajoule_base_unit = ScaledUnit(factor=1e+21, master=meter*newton, n...
#     zettajoules = Unit({ScaledUnit(factor=1e+21, master=meter*newton, name...
#     zettaliter = Unit({ScaledUnit(factor=1e+21, master=decimeter**3, name=...
#     zettaliter_base_unit = ScaledUnit(factor=1e+21, master=decimeter**3, n...
#     zettaliters = Unit({ScaledUnit(factor=1e+21, master=decimeter**3, name...
#     zettameter = Unit({BaseUnit(base_dim=BaseDimension("length"), name="ze...
#     zettameter_base_unit = BaseUnit(base_dim=BaseDimension("length"), name...
#     zettameters = Unit({BaseUnit(base_dim=BaseDimension("length"), name="z...
#     zettamolar = Unit({ScaledUnit(factor=1e+21, master=mole/liter, name='z...
#     zettamolar_base_unit = ScaledUnit(factor=1e+21, master=mole/liter, nam...
#     zettamolars = Unit({ScaledUnit(factor=1e+21, master=mole/liter, name='...
#     zettanewton = Unit({ScaledUnit(factor=1e+21, master=kilogram*m...cond*...
#     zettanewton_base_unit = ScaledUnit(factor=1e+21, master=kilogram*meter...
#     zettanewtons = Unit({ScaledUnit(factor=1e+21, master=kilogram*m...cond...
#     zettapascal = Unit({ScaledUnit(factor=1e+21, master=newton/(meter**2),...
#     zettapascal_base_unit = ScaledUnit(factor=1e+21, master=newton/(meter*...
#     zettapascals = Unit({ScaledUnit(factor=1e+21, master=newton/(meter**2)...
#     zettasecond = Unit({BaseUnit(base_dim=BaseDimension("time"), name="zet...
#     zettasecond_base_unit = BaseUnit(base_dim=BaseDimension("time"), name=...
#     zettaseconds = Unit({BaseUnit(base_dim=BaseDimension("time"), name="ze...
#
# AUTHOR
#     Christopher M. Bruns
#
# CREDITS
#     []
#
# FILE
#     /Users/choderaj/miniconda3/lib/python3.5/site-packages/simtk/unit/__init__.py

# %% [markdown]
# ## Accesssors for System attributes and Forces
#
# The [`System`](http://docs.openmm.org/7.1.0/api-python/generated/simtk.openmm.openmm.System.html#simtk.openmm.openmm.System) object has a number of useful accessors for examining the contents of the system and

# %%
# Get the number of particles in the System
print('The system has %d particles' % system.getNumParticles())
# Print a few particle masses
for index in range(5):
    print('Particle %5d has mass %12.3f amu' % (index, system.getParticleMass(index) / unit.amu))
# Print number of constraints
print('The system has %d constraints' % system.getNumConstraints())
# Get the number of forces and iterate through them
print('There are %d forces' % system.getNumForces())
for (index, force) in enumerate(system.getForces()):
    print('Force %5d : %s' % (index, force.__class__.__name__))
# Out:
# The system has 512 particles
# Particle     0 has mass       39.900 amu
# Particle     1 has mass       39.900 amu
# Particle     2 has mass       39.900 amu
# Particle     3 has mass       39.900 amu
# Particle     4 has mass       39.900 amu
# The system has 0 constraints
# There are 1 forces
# Force     0 : NonbondedForce

# %% [markdown]
# ### Define positions for the Lennard-Jones particles
#
# To compute energies or forces, we will need to define some positions for the system before we can compute energies or forces.
# We'll generate some randomly, but as we will see later, there are many more ways to load molecular positions.

# %%
positions = box_edge * np.random.rand(nparticles,3) 
print(positions)
# Out:
# [[ 62.42671981  20.89465498  48.60474262]
#  [  6.53028081  71.39761327  21.8076328 ]
#  [ 29.53783841  65.55634362  58.15669054]
#  ...,
#  [ 53.36038058  42.67019762  47.37767215]
#  [ 65.07506133  36.17425014  68.85405609]
#  [ 66.73525626  72.10376368  49.95839076]] A

# %% [markdown]
# ## Computing energies and forces
#
# To compute energies and forces efficiently, OpenMM requires you create a [`Context`](http://docs.openmm.org/7.1.0/api-python/generated/simtk.openmm.openmm.Context.html#simtk.openmm.openmm.Context) that handles the computation on a particular piece of hardware. This could be a GPU or CPU using a specific set of fast computation kernels.
#
# OpenMM forces us to explicitly move data (positions, velocities, forces) into and out of the `Context` through specific calls so that we remember that each of these operations carries overhead of moving data across the bus to the GPU, for example. To achieve maximum speed, OpenMM can perform a number of operations---such as integrating many molecular dynamics steps---fully on the GPU without slowing things down by moving data back and forth over the bus. We'll see examples of this soon.
#
# First, we just want to compute energies and forces and then minimize the energy of our system. To do that, we first need to create an [`Integrator`](http://docs.openmm.org/7.1.0/userguide/application.html#integrators) that will be bound to the [`Context`](http://docs.openmm.org/7.1.0/api-python/generated/simtk.openmm.openmm.Context.html#simtk.openmm.openmm.Context):

# %%
# Create an integrator
timestep = 1.0 * unit.femtoseconds
integrator = openmm.VerletIntegrator(timestep)
# Create a Context using the default platform (the fastest abailable one is picked automatically)
# NOTE: The integrator is bound irrevocably to the context, so we can't reuse it
context = openmm.Context(system, integrator)

# %% [markdown]
# We will look at [`Integrator`](http://docs.openmm.org/7.1.0/userguide/application.html#integrators) objects more in depth in [Module 02 - Integrators and Sampling](https://github.com/choderalab/openmm-tutorials/blob/master/02%20-%20Integrators%20and%20sampling.ipynb)
#
# We can also optionally specify which platform we want. OpenMM comes with the following [`Platforms:`](http://docs.openmm.org/7.1.0/userguide/application.html#platforms)
# * [`Reference`](http://docs.openmm.org/7.1.0/userguide/library.html#platforms) - A slow double-precision single-threaded CPU-only implementation intended for comparing fast implementations with a "verifiably correct" one
# * [`CPU`](http://docs.openmm.org/7.1.0/userguide/library.html#cpu-platform) - A fast multithreaded mixed-precision CPU-only implementation
# * [`OpenCL`](http://docs.openmm.org/7.1.0/userguide/library.html#opencl-platform) - A highly portable OpenCL implementation that can be used with GPU or CPU OpenCL drivers; supports multiple precision models (single, mixed, double)
# * [`CUDA`](http://docs.openmm.org/7.1.0/userguide/library.html#cuda-platform) - The fastest implementation that uses [CUDA](https://developer.nvidia.com/cuda-downloads) for NVIDIA GPUs; supports multiple precision models (single, mixed, double)

# %%
# We have to create a new integrator for every Context since it takes ownership of the integrator we pass it
integrator = openmm.VerletIntegrator(timestep)
# Create a Context using the multithreaded mixed-precision CPU platform
platform = openmm.Platform.getPlatformByName('CPU')
context = openmm.Context(system, integrator, platform)

# %% [markdown]
# The `System` object can be used by multiple `Contexts` because the `System` is copied and converted to the efficient `Platform` specific kernels inside the `Context` object. Changing parameters or adding new `Force`'s on the Python `System` itself will not update the representation inside the `Context`.

# %%
from copy import deepcopy
# Create a new integrator we can throw away
throwaway_integrator = openmm.VerletIntegrator(timestep)
# Copy the System object for this example
copy_system = deepcopy(system)
throwaway_context = openmm.Context(copy_system, throwaway_integrator)
# Change something in the Python System, e.g. double the box size
copy_system.setDefaultPeriodicBoxVectors(*box_vectors*2)
# Observe how the box size in the Context and Python System are different
print([vector for i, vector in enumerate(copy_system.getDefaultPeriodicBoxVectors())])
print([vector for i, vector in enumerate(throwaway_context.getState().getPeriodicBoxVectors())])
# Cleanup
del throwaway_integrator, throwaway_context

# %% [markdown]
# There are ways to update paramters in an existing `Context`, but that topic will be covered in later tutorials.
#
# Once we have a [`Context`](http://docs.openmm.org/7.1.0/api-python/generated/simtk.openmm.openmm.Context.html#simtk.openmm.openmm.Context), we need to tell OpenMM we want to retrieve the energy and forces for a specific set of particle positions. This is done by retrieving a [`State`](http://docs.openmm.org/7.1.0/api-python/generated/simtk.openmm.openmm.State.html#simtk.openmm.openmm.State) object from the [`Context`](http://docs.openmm.org/7.1.0/api-python/generated/simtk.openmm.openmm.Context.html#simtk.openmm.openmm.Context) that contains *only* the information we want to retrieve so as to minimize the amount of data that needs to be sent over the bus from a GPU:

# %%
# Set the positions
context.setPositions(positions)
# Retrieve the energy and forces
state = context.getState(getEnergy=True, getForces=True)
potential_energy = state.getPotentialEnergy()
print('Potential energy: %s' % potential_energy)
forces = state.getForces()
print('Forces: %s' % forces[0:5])
# Out:
# Potential energy: 720099581392564.6 kJ/mol
# Forces: [(0.0, 0.0, 0.0), (431.6894226074219, 105.30390930175781, -221.93014526367188), (-16.329151153564453, 19.887710571289062, 4.469150543212891), (-80834888.0, 112865840.0, -23972412.0), (273992.15625, 5550802.5, -3584620.0)] kJ/(nm mol)

# %% [markdown]
# Note that the forces are returned as a `list` of tuples with units attached. If we want a numpy array instead, we could convert it, but it's much easier just use the `asNumpy=True` argument to [`state.getForces`](http://docs.openmm.org/7.1.0/api-python/generated/simtk.openmm.openmm.State.html#simtk.openmm.openmm.State.getForces)

# %%
# Get forces as numpy array
forces = state.getForces(asNumpy=True)
print('Forces: %s' % forces)
# Out:
# Forces: [[  0.00000000e+00   0.00000000e+00   0.00000000e+00]
#  [  4.31689423e+02   1.05303909e+02  -2.21930145e+02]
#  [ -1.63291512e+01   1.98877106e+01   4.46915054e+00]
#  ...,
#  [  4.40171808e-01   2.17729568e+00   6.70855188e+00]
#  [ -6.55915886e-02  -8.21644589e-02  -2.15165660e-01]
#  [  1.65790260e-01  -1.11425519e-02  -1.09918743e-01]] kJ/(nm mol)

# %% [markdown]
# ## Minimizing the potential energy
#
# You'll notice the energy and force magnitude is pretty large:

# %%
# Compute the energy
state = context.getState(getEnergy=True, getForces=True)
potential_energy = state.getPotentialEnergy()
print('Potential energy: %s' % potential_energy)
# Compute the force magnitude
forces = state.getForces(asNumpy=True)
force_magnitude = (forces**2).sum().sqrt()
print('Force magnitude: %s' % force_magnitude)
# Out:
# Potential energy: 720099581392563.9 kJ/mol
# Force magnitude: 5.516501691702616e+17 kJ/(nm mol)

# %% [markdown]
# If we tried to do dynamics at this point, the system will likely explode!
#
# OpenMM provides a [`LocalEnergyMinimizer`](http://docs.openmm.org/7.1.0/api-python/generated/simtk.openmm.openmm.LocalEnergyMinimizer.html#simtk.openmm.openmm.LocalEnergyMinimizer) that can be used to bring the force magnitude to be low enough to be able to run a simulation that won't explode.

# %%
# Minimize the potential energy
openmm.LocalEnergyMinimizer.minimize(context)

# Compute the energy and force magnitude after minimization
state = context.getState(getEnergy=True, getForces=True)
potential_energy = state.getPotentialEnergy()
print('Potential energy: %s' % potential_energy)
forces = state.getForces(asNumpy=True)
force_magnitude = (forces**2).sum().sqrt()
print('Force magnitude: %s' % force_magnitude)
# Out:
# Potential energy: -206.79064675255975 kJ/mol
# Force magnitude: 147.0268501931089 kJ/(nm mol)

# %% [markdown]
# ## Serializing the System object to disk or for transport over the network
#
# You can serialize and restore `System` objects as a string (which can be written to disk) via the [`XmlSerializer`](http://docs.openmm.org/7.1.0/api-python/generated/simtk.openmm.openmm.XmlSerializer.html#simtk.openmm.openmm.XmlSerializer) class:

# %%
# Serialize to a string
system_xml = openmm.XmlSerializer.serialize(system)
# Restore from a string
restored_system = openmm.XmlSerializer.deserialize(system_xml)
assert(system.getNumParticles() == restored_system.getNumParticles())

# %%
print(system_xml)
# Out:
# <?xml version="1.0" ?>
# <System openmmVersion="7.1.1" type="System" version="1">
# 	<PeriodicBoxVectors>
# 		<A x="7.383215917138144" y="0" z="0"/>
# 		<B x="0" y="7.383215917138144" z="0"/>
# 		<C x="0" y="0" z="7.383215917138144"/>
# 	</PeriodicBoxVectors>
# 	<Particles>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 		<Particle mass="39.9"/>
# 	</Particles>
# 	<Constraints/>
# 	<Forces>
# 		<Force alpha="0" cutoff="1.02" dispersionCorrection="1" ewaldTolerance=".0005" forceGroup="0" method="2" nx="0" ny="0" nz="0" recipForceGroup="-1" rfDielectric="78.3" switchingDistance=".8500000000000001" type="NonbondedForce" useSwitchingFunction="1" version="1">
# 			<Particles>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 				<Particle eps=".995792" q="0" sig=".34"/>
# 			</Particles>
# 			<Exceptions/>
# 		</Force>
# 	</Forces>
# </System>

# %% [markdown]
# ## Load a molecular system defined by AMBER, CHARMM, or gromacs
#
# The OpenMM [`app` layer](http://docs.openmm.org/7.1.0/userguide/application.html#using-amber-files) provides convenience classes that help you load in systems defined in AMBER, CHARMM, or gromacs.

# %% [markdown]
# ### Loading an AMBER system
#
# We can use [`AmberPrmtopFile`](http://docs.openmm.org/7.1.0/api-python/generated/simtk.openmm.app.amberprmtopfile.AmberPrmtopFile.html#simtk.openmm.app.amberprmtopfile.AmberPrmtopFile) to load an Amber `prmtop` file and [`InpcrdFile`](http://docs.openmm.org/7.1.0/api-python/generated/simtk.openmm.app.amberinpcrdfile.AmberInpcrdFile.html#simtk.openmm.app.amberinpcrdfile.AmberInpcrdFile) to load an `inpcrd` file:

# %%
# Load in an AMBER system
from simtk.openmm import app
prmtop = app.AmberPrmtopFile('resources/alanine-dipeptide-implicit.prmtop')
inpcrd = app.AmberInpcrdFile('resources/alanine-dipeptide-implicit.inpcrd')
system = prmtop.createSystem(nonbondedMethod=app.NoCutoff, implicitSolvent=app.OBC2, constraints=app.HBonds)
positions = inpcrd.getPositions(asNumpy=True)

# Compute the potential energy
def compute_potential(system, positions):
    """Print the potential energy given a System and positions."""
    integrator = openmm.VerletIntegrator(1.0 * unit.femtoseconds)
    context = openmm.Context(system, integrator)
    context.setPositions(positions)
    print('Potential energy: %s' % context.getState(getEnergy=True).getPotentialEnergy())
    # Clean up
    del context, integrator
    
compute_potential(system, positions)
# Out:
# Potential energy: -137.4395293410778 kJ/mol

# %% [markdown]
# ## Loading a CHARMM system
#
# We can also [load CHARMM files](http://docs.openmm.org/7.1.0/userguide/application.html#using-charmm-files):

# %%
# Load in a CHARMM system
from simtk.openmm import app
psf = app.CharmmPsfFile('resources/ala_ala_ala.psf')
pdbfile = app.PDBFile('resources/ala_ala_ala.pdb')
params = app.CharmmParameterSet('resources/charmm22.rtf', 'resources/charmm22.par')
system = psf.createSystem(params, nonbondedMethod=app.NoCutoff, constraints=app.HBonds)
positions = pdbfile.getPositions(asNumpy=True)
compute_potential(system, positions)
# Out:
# Potential energy: 187615.39653015137 kJ/mol

# %% [markdown]
# ## Loading a gromacs system
#
# We can also [load gromacs files](http://docs.openmm.org/7.1.0/userguide/application.html#using-gromacs-files), though you'll want to have the gromacs parameter files installed first.
#
# You can install a version of gromacs via `conda` with:
# ```
# conda install --yes -c bioconda gromacs
# ```

# %%
# Load in a gromacs system
from simtk.openmm import app
gro = app.GromacsGroFile('resources/input.gro')
# Make sure you change this to your appropriate gromacs include directory!
gromacs_include_filepath = '/Users/choderaj/miniconda3/share/gromacs/top/'
top = app.GromacsTopFile('resources/input.top', periodicBoxVectors=gro.getPeriodicBoxVectors(), includeDir=gromacs_include_filepath)
system = top.createSystem(nonbondedMethod=app.PME, nonbondedCutoff=1*unit.nanometer, constraints=app.HBonds)
positions = gro.getPositions(asNumpy=True)
compute_potential(system, positions)
# Out:
# Potential energy: -115290.90370344353 kJ/mol

# %% [markdown]
# ## Creating a `System` using the OpenMM `ForceField` class
#
# OpenMM also provides a number of [force fields](http://docs.openmm.org/7.1.0/userguide/application.html#force-fields) that have been converted into a [universal XML force field description format](http://docs.openmm.org/7.1.0/userguide/application.html#writing-the-xml-file) that can also be [extended in a modular manner](http://docs.openmm.org/7.1.0/userguide/application.html#extending-forcefield). Several [common AMBER protein force fields are provided](http://docs.openmm.org/7.1.0/userguide/application.html#force-fields) that work well for protein systems in which all atoms are already present.

# %%
# Create an OpenMM system using the ForceField class
pdb = app.PDBFile('resources/input.pdb')
forcefield = app.ForceField('amber99sb.xml', 'tip3p.xml')
system = forcefield.createSystem(pdb.topology, nonbondedMethod=app.PME, nonbondedCutoff=1*unit.nanometer, constraints=app.HBonds)
positions = pdb.positions
compute_potential(system, positions)
# Out:
# Potential energy: -115281.71510718693 kJ/mol

# %% [markdown]
# ## Visualizing the system and using `Topology` objects

# %% [markdown]
# While the `System` objects don't contain any information on the *identities* of the particles or how these are organized into residues or molecules, we can extract a [`Topology`](http://docs.openmm.org/7.1.0/api-python/generated/simtk.openmm.app.topology.Topology.html#simtk.openmm.app.topology.Topology) object that provides this information from a PDB file:

# %%
# Extract the topology from a PDB file
pdbfile = app.PDBFile('resources/alanine-dipeptide-implicit.pdb')
positions = pdbfile.getPositions()
topology = pdbfile.getTopology()

# %% [markdown]
# OpenMM provides a way to write a frame to a PDB file should you want to visualize your initial configuration:

# %%
# Write out a PDB file
with open('output.pdb', 'w') as outfile:
    app.PDBFile.writeFile(topology, positions, outfile)

# %% [markdown]
# If working in a Jupyter notebook, we can use [`mdtraj`](http://mdtraj.org) and [`nglview`](https://github.com/arose/nglview) to visualize the system:

# %%
# Create an MDTraj Trajectory object
import mdtraj
mdtraj_topology = mdtraj.Topology.from_openmm(topology)
traj = mdtraj.Trajectory(positions/unit.nanometers, mdtraj_topology)

# View it in nglview
import nglview
view = nglview.show_mdtraj(traj)
view.add_ball_and_stick('all')
view.center_view(zoom=True)
view

# %% [markdown]
# ## Prebuilt systems with `openmmtools.testsystems`

# %% [markdown]
# The [`openmmtools.testsystems`](http://openmmtools.readthedocs.io/en/latest/testsystems.html) module provides a number
# of pre-built test systems that are very useful for testing your code or benchmarking your algorithms. The full list of test systems can be found [here](http://openmmtools.readthedocs.io/en/latest/testsystems.html), but we'll highlight a few below.

# %%
from openmmtools import testsystems

t = testsystems.HarmonicOscillator()
system, positions, topology = t.system, t.positions, t.topology

print(positions)
help(t)
# Out:
# [[ 0.  0.  0.]] A
# Help on HarmonicOscillator in module openmmtools.testsystems object:
#
# class HarmonicOscillator(TestSystem)
#  |  Create a 3D harmonic oscillator, with a single particle confined in an isotropic harmonic well.
#  |
#  |  Parameters
#  |  ----------
#  |  K : simtk.unit.Quantity, optional, default=100.0 * unit.kilocalories_per_mole/unit.angstrom**2
#  |      harmonic restraining potential
#  |  mass : simtk.unit.Quantity, optional, default=39.948 * unit.amu
#  |      particle mass
#  |  U0 : simtk.unit.Quantity, optional, default=0.0 * unit.kilocalories_per_mole
#  |      Potential offset for harmonic oscillator
#  |
#  |  The functional form is given by
#  |
#  |  U(x) = (K/2) * ( (x-x0)^2 + y^2 + z^2 ) + U0
#  |
#  |  Attributes
#  |  ----------
#  |  system : simtk.openmm.System
#  |      Openmm system with the harmonic oscillator
#  |  positions : list
#  |      positions of harmonic oscillator
#  |
#  |  Context parameters
#  |  ------------------
#  |  testsystems_HarmonicOscillator_K
#  |      Spring constant of harmonic oscillator
#  |  testsystems_HarmonicOscillator_x0
#  |      Reference x position for harmonic oscillator
#  |  testsystems_HarmonicOscillator_U0
#  |      Reference potential additive constant for harmonic oscillator
#  |
#  |  Notes
#  |  -----
#  |
#  |  The natural period of a harmonic oscillator is T = sqrt(m/K), so you will want to use an
#  |  integration timestep smaller than ~ T/10.
#  |
#  |  The standard deviation in position in each dimension is sigma = (kT / K)^(1/2)
#  |
#  |  The expectation and standard deviation of the potential energy of a 3D harmonic oscillator is (3/2)kT.
#  |
#  |  Examples
#  |  --------
#  |
#  |  Create a 3D harmonic oscillator with default parameters:
#  |
#  |  >>> ho = HarmonicOscillator()
#  |  >>> (system, positions) = ho.system, ho.positions
#  |
#  |  Create a harmonic oscillator with specified mass and spring constant:
#  |
#  |  >>> mass = 12.0 * unit.amu
#  |  >>> K = 1.0 * unit.kilocalories_per_mole / unit.angstroms**2
#  |  >>> ho = HarmonicOscillator(K=K, mass=mass)
#  |  >>> (system, positions) = ho.system, ho.positions
#  |
#  |  Get a list of the available analytically-computed properties.
#  |
#  |  >>> print(ho.analytical_properties)
#  |  ['potential_expectation', 'potential_standard_deviation']
#  |
#  |  Compute the potential expectation and standard deviation
#  |
#  |  >>> import simtk.unit as u
#  |  >>> thermodynamic_state = ThermodynamicState(temperature=298.0*u.kelvin, system=system)
#  |  >>> potential_mean = ho.get_potential_expectation(thermodynamic_state)
#  |  >>> potential_stddev = ho.get_potential_standard_deviation(thermodynamic_state)
#  |
#  |  TODO:
#  |  * Add getters and setters for K, x0, U0 that access current global parameter in system
#  |  * Add method to compute free energy of the harmonic oscillator(s)
#  |
#  |  Method resolution order:
#  |      HarmonicOscillator
#  |      TestSystem
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, K=Quantity(value=100.0, unit=kilocalorie/(angstrom**2*mole)), mass=Quantity(value=39.948, unit=dalton), U0=Quantity(value=0.0, unit=kilojoule/mole), **kwargs)
#  |      Abstract base class for test system.
#  |
#  |      Parameters
#  |      ----------
#  |
#  |  get_potential_expectation(self, state)
#  |      Return the expectation of the potential energy, computed analytically or numerically.
#  |
#  |      Arguments
#  |      ---------
#  |
#  |      state : ThermodynamicState with temperature defined
#  |          The thermodynamic state at which the property is to be computed.
#  |
#  |      Returns
#  |      -------
#  |
#  |      potential_mean : simtk.unit.Quantity compatible with simtk.unit.kilojoules_per_mole
#  |          The expectation of the potential energy.
#  |
#  |  get_potential_standard_deviation(self, state)
#  |      Return the standard deviation of the potential energy, computed analytically or numerically.
#  |
#  |      Arguments
#  |      ---------
#  |
#  |      state : ThermodynamicState with temperature defined
#  |          The thermodynamic state at which the property is to be computed.
#  |
#  |      Returns
#  |      -------
#  |
#  |      potential_stddev : simtk.unit.Quantity compatible with simtk.unit.kilojoules_per_mole
#  |          potential energy standard deviation if implemented, or else None
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from TestSystem:
#  |
#  |  reduced_potential_expectation(self, state_sampled_from, state_evaluated_in)
#  |      Calculate the expected potential energy in state_sampled_from, divided by kB * T in state_evaluated_in.
#  |
#  |      Notes
#  |      -----
#  |
#  |      This is not called get_reduced_potential_expectation because this function
#  |      requires two, not one, inputs.
#  |
#  |  serialize(self)
#  |      Return the System and positions in serialized XML form.
#  |
#  |      Returns
#  |      -------
#  |
#  |      system_xml : str
#  |          Serialized XML form of System object.
#  |
#  |      state_xml : str
#  |          Serialized XML form of State object containing particle positions.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from TestSystem:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  analytical_properties
#  |      A list of available analytical properties, accessible via 'get_propertyname(thermodynamic_state)' calls.
#  |
#  |  name
#  |      The name of the test system.
#  |
#  |  positions
#  |      The simtk.unit.Quantity object containing the particle positions, with units compatible with simtk.unit.nanometers.
#  |
#  |  system
#  |      The simtk.openmm.System object corresponding to the test system.
#  |
#  |  topology
#  |      The simtk.openmm.app.Topology object corresponding to the test system.

# %%
# Create a Lennard-Jones cluster with a harmonic spherical restraint:
t = testsystems.LennardJonesCluster()

def visualize(t):
    import mdtraj
    mdtraj_topology = mdtraj.Topology.from_openmm(t.topology)
    traj = mdtraj.Trajectory([t.positions/unit.nanometers], mdtraj_topology)

    # View it in nglview
    import nglview
    view = nglview.show_mdtraj(traj)
    if t.system.getNumParticles() < 2000:
        view.add_ball_and_stick('all')
    view.center_view(zoom=True)
    return view

visualize(t)

# %%
t = testsystems.LennardJonesFluid(reduced_density=0.90)
visualize(t)

# %%
t = testsystems.WaterBox()
visualize(t)

# %%
t = testsystems.AlanineDipeptideVacuum()
visualize(t)

# %%
# The Joint AMBER-CHARMM (JAC) DHFR in explicit solvent benchmark system
t = testsystems.DHFRExplicit()
visualize(t)

# %% [markdown]
# There are lots and lots of systems defined! Try some!

# %%
# Get all subclasses of type `TestSystem`
from openmmtools.tests.test_testsystems import get_all_subclasses
for t in get_all_subclasses(testsystems.TestSystem):
    print(t.__name__)
# Out:
# MethanolBox
# AMOEBAProteinBox
# Diatom
# IdealGas
# WaterBox
# FlexibleReactionFieldWaterBox
# FlexiblePMEWaterBox
# DischargedWaterBoxHsites
# FiveSiteWaterBox
# PMEWaterBox
# FlexibleWaterBox
# FlexibleDischargedWaterBox
# GiantFlexibleDischargedWaterBox
# AlchemicalWaterBox
# DischargedWaterBox
# FourSiteWaterBox
# GiantFlexibleWaterBox
# TolueneVacuum
# PowerOscillator
# AMOEBAIonBox
# CustomGBForceSystem
# DiatomicFluid
# UnconstrainedDiatomicFluid
# ConstrainedDiatomicFluid
# DipolarFluid
# UnconstrainedDipolarFluid
# ConstrainedDipolarFluid
# CustomLennardJonesFluidMixture
# SrcExplicit
# SrcExplicitReactionField
# HarmonicOscillatorArray
# SodiumChlorideCrystal
# MolecularIdealGas
# HostGuestVacuum
# LennardJonesCluster
# LysozymeImplicit
# HarmonicOscillator
# HostGuestExplicit
# AlanineDipeptideVacuum
# AlchemicalAlanineDipeptide
# LennardJonesFluid
# LennardJonesFluidTruncated
# LennardJonesFluidSwitched
# LennardJonesGrid
# HostGuestImplicit
# HostGuestImplicitHCT
# HostGuestImplicitOBC1
# HostGuestImplicitGBn2
# HostGuestImplicitOBC2
# HostGuestImplicitGBn
# AlanineDipeptideExplicit
# TolueneImplicit
# TolueneImplicitHCT
# TolueneImplicitOBC1
# TolueneImplicitGBn2
# TolueneImplicitGBn
# TolueneImplicitOBC2
# SrcImplicit
# LennardJonesPair
# DNADodecamerExplicit
# DHFRExplicit
# WCAFluid
# AlanineDipeptideImplicit
# CustomExternalForcesTestSystem
# ConstraintCoupledHarmonicOscillator

# %% [markdown]
# # Wrap-up
#
# We've reviewed a myriad of ways that you can create OpenMM [`System`](http://docs.openmm.org/7.1.0/api-python/generated/simtk.openmm.openmm.System.html#simtk.openmm.openmm.System) objects.
#
# To recap, there are many ways to create or import OpenMM `System` objects:
# * We can assemble all the particles and define their interactions ourselves programmatically using the OpenMM C++ API
# * We could load in a serialized version of the `System` object via the built-in XML serializer
# * We can use the various importers in the [`simtk.openmm.app`](http://docs.openmm.org/7.1.0/api-python/app.html) layer to read in a system definition in AMBER, CHARMM, or gromacs format
# * We can create our own `System` object from a PDB file using the OpenMM [`ForceField`](http://docs.openmm.org/7.1.0/userguide/application.html#force-fields) facility
# * We can use a large variety of pre-built test systems provided by the [`openmmtools.testsystems`](http://openmmtools.readthedocs.io) module for testing code on a battery of different system types with different kinds of forces
